# %%
# Import des librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Fichier des tweets à récupérer sur : https://www.kaggle.com/crowdflower/twitter-airline-sentiment?select=Tweets.csv

# path = 'D:/ML_Datasets/Tweets2/' # à adapter = répertoire de stockage du dataset
data_T0 = pd.read_csv("Tweets.csv")
# Le dataset est dans le même répertoire.
print(data_T0.shape)
# Out:
# (14640, 15)

# %%
# Filtre de tweets avec un niveau de confiance à 1 sur le sentiment
data_T1 = data_T0[data_T0['airline_sentiment_confidence']==1]
print(data_T1.shape)

data_T1.groupby('airline_sentiment')['airline_sentiment'].count()
# Out:
# (10445, 15)
# airline_sentiment
# negative    7382
# neutral     1548
# positive    1515
# Name: airline_sentiment, dtype: int64

# %%
data_T1
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                           1.0
# 3      570301031407624196          negative                           1.0
# 4      570300817074462722          negative                           1.0
# 5      570300767074181121          negative                           1.0
# 9      570295459631263746          positive                           1.0
# ...                   ...               ...                           ...
# 14631  569588464896876545          negative                           1.0
# 14633  569587705937600512          negative                           1.0
# 14636  569587371693355008          negative                           1.0
# 14637  569587242672398336           neutral                           1.0
# 14638  569587188687634433          negative                           1.0
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# 9                         NaN                        NaN  Virgin America
# ...                       ...                        ...             ...
# 14631              Bad Flight                     1.0000        American
# 14633        Cancelled Flight                     1.0000        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
#
#       airline_sentiment_gold             name negativereason_gold  \
# 0                        NaN          cairdin                 NaN
# 3                        NaN         jnardino                 NaN
# 4                        NaN         jnardino                 NaN
# 5                        NaN         jnardino                 NaN
# 9                        NaN       YupitsTate                 NaN
# ...                      ...              ...                 ...
# 14631                    NaN         MDDavis7                 NaN
# 14633                    NaN  RussellsWriting                 NaN
# 14636                    NaN         itsropes                 NaN
# 14637                    NaN         sanyabun                 NaN
# 14638                    NaN       SraJackson                 NaN
#
#        retweet_count                                               text  \
# 0                  0                @VirginAmerica What @dhepburn said.
# 3                  0  @VirginAmerica it's really aggressive to blast...
# 4                  0  @VirginAmerica and it's a really big bad thing...
# 5                  0  @VirginAmerica seriously would pay $30 a fligh...
# 9                  0  @VirginAmerica it was amazing, and arrived an ...
# ...              ...                                                ...
# 14631              0  @AmericanAir thx for nothing on getting us out...
# 14633              0  @AmericanAir my flight was Cancelled Flightled...
# 14636              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14637              0  @AmericanAir Please bring American Airlines to...
# 14638              0  @AmericanAir you have my money, you change my ...
#
#       tweet_coord              tweet_created tweet_location  \
# 0             NaN  2015-02-24 11:35:52 -0800            NaN
# 3             NaN  2015-02-24 11:15:36 -0800            NaN
# 4             NaN  2015-02-24 11:14:45 -0800            NaN
# 5             NaN  2015-02-24 11:14:33 -0800            NaN
# 9             NaN  2015-02-24 10:53:27 -0800    Los Angeles
# ...           ...                        ...            ...
# 14631         NaN  2015-02-22 12:04:07 -0800             US
# 14633         NaN  2015-02-22 12:01:06 -0800    Los Angeles
# 14636         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638         NaN  2015-02-22 11:59:02 -0800     New Jersey
#
#                     user_timezone
# 0      Eastern Time (US & Canada)
# 3      Pacific Time (US & Canada)
# 4      Pacific Time (US & Canada)
# 5      Pacific Time (US & Canada)
# 9      Eastern Time (US & Canada)
# ...                           ...
# 14631  Eastern Time (US & Canada)
# 14633                     Arizona
# 14636                         NaN
# 14637                         NaN
# 14638  Eastern Time (US & Canada)
#
# [10445 rows x 15 columns]

# %%
# Sélection de 1500 tweets positif et 1500 tweets négatifs

data_Tneg = data_T1[data_T1['airline_sentiment']=='negative'].iloc[0:1500]
data_Tpos = data_T1[data_T1['airline_sentiment']=='positive'].iloc[0:1500]
data_T = pd.concat((data_Tneg, data_Tpos), axis=0)
data_T.shape
# Out:
# (3000, 15)

# %% [markdown]
# ## Nettoyage du texte

# %%
# Tokenizer
import nltk
nltk.download('wordnet')
from nltk.tokenize import sent_tokenize, word_tokenize

def tokenizer_fct(sentence) :
    # print(sentence)
    sentence_clean = sentence.replace('-', ' ').replace('+', ' ').replace('/', ' ').replace('#', ' ')
    word_tokens = word_tokenize(sentence_clean)
    return word_tokens

# Stop words
from nltk.corpus import stopwords
stop_w = list(set(stopwords.words('english'))) + ['[', ']', ',', '.', ':', '?', '(', ')']

def stop_word_filter_fct(list_words) :
    filtered_w = [w for w in list_words if not w in stop_w]
    filtered_w2 = [w for w in filtered_w if len(w) > 2]
    return filtered_w2

# lower case et alpha
def lower_start_fct(list_words) :
    lw = [w.lower() for w in list_words if (not w.startswith("@")) 
    #                                   and (not w.startswith("#"))
                                       and (not w.startswith("http"))]
    return lw

# Lemmatizer (base d'un mot)
from nltk.stem import WordNetLemmatizer

def lemma_fct(list_words) :
    lemmatizer = WordNetLemmatizer()
    lem_w = [lemmatizer.lemmatize(w) for w in list_words]
    return lem_w

# Fonction de préparation du texte pour le bag of words (Countvectorizer et Tf_idf, Word2Vec)
def transform_bow_fct(desc_text) :
    word_tokens = tokenizer_fct(desc_text)
    sw = stop_word_filter_fct(word_tokens)
    lw = lower_start_fct(sw)
    # lem_w = lemma_fct(lw)    
    transf_desc_text = ' '.join(lw)
    return transf_desc_text

# Fonction de préparation du texte pour le bag of words avec lemmatization
def transform_bow_lem_fct(desc_text) :
    word_tokens = tokenizer_fct(desc_text)
    sw = stop_word_filter_fct(word_tokens)
    lw = lower_start_fct(sw)
    lem_w = lemma_fct(lw)    
    transf_desc_text = ' '.join(lem_w)
    return transf_desc_text

# Fonction de préparation du texte pour le Deep learning (USE et BERT)
def transform_dl_fct(desc_text) :
    word_tokens = tokenizer_fct(desc_text)
#    sw = stop_word_filter_fct(word_tokens)
    lw = lower_start_fct(word_tokens)
    # lem_w = lemma_fct(lw)    
    transf_desc_text = ' '.join(lw)
    return transf_desc_text

data_T['sentence_bow'] = data_T0['text'].apply(lambda x : transform_bow_fct(x))
data_T['sentence_bow_lem'] = data_T0['text'].apply(lambda x : transform_bow_lem_fct(x))
data_T['sentence_dl'] = data_T0['text'].apply(lambda x : transform_dl_fct(x))
data_T.shape
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# (3000, 18)

# %%
data_T['sentence_dl']

# %%
data_T.to_csv("data_tweets2_3000.csv")

# %% [markdown]
# # Préparation commune des traitements

# %%
# Import des librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import pickle
import time
from sklearn import cluster, metrics
from sklearn import manifold, decomposition
import logging

logging.disable(logging.WARNING) # disable WARNING, INFO and DEBUG logging everywhere

# %% [markdown]
# ## Lecture dataset

# %%
data_T =  pd.read_csv("data_tweets2_3000.csv")
print(data_T.shape)
data_T
# Out:
# (3000, 19)
#       Unnamed: 0            tweet_id airline_sentiment  \
# 0              3  570301031407624196          negative
# 1              4  570300817074462722          negative
# 2              5  570300767074181121          negative
# 3             17  570276917301137409          negative
# 4             24  570256553502068736          negative
# ...          ...                 ...               ...
# 2995       14336  569631742631354369          positive
# 2996       14363  569627200133197824          positive
# 2997       14374  569625356942098432          positive
# 2998       14383  569623364337168384          positive
# 2999       14391  569621883282280448          positive
#
#       airline_sentiment_confidence          negativereason  \
# 0                              1.0              Bad Flight
# 1                              1.0              Can't Tell
# 2                              1.0              Can't Tell
# 3                              1.0              Bad Flight
# 4                              1.0  Customer Service Issue
# ...                            ...                     ...
# 2995                           1.0                     NaN
# 2996                           1.0                     NaN
# 2997                           1.0                     NaN
# 2998                           1.0                     NaN
# 2999                           1.0                     NaN
#
#       negativereason_confidence         airline airline_sentiment_gold  \
# 0                        0.7033  Virgin America                    NaN
# 1                        1.0000  Virgin America                    NaN
# 2                        0.6842  Virgin America                    NaN
# 3                        1.0000  Virgin America                    NaN
# 4                        0.3557  Virgin America                    NaN
# ...                         ...             ...                    ...
# 2995                        NaN        American                    NaN
# 2996                        NaN        American                    NaN
# 2997                        NaN        American                    NaN
# 2998                        NaN        American                    NaN
# 2999                        NaN        American                    NaN
#
#                 name negativereason_gold  retweet_count  \
# 0           jnardino                 NaN              0
# 1           jnardino                 NaN              0
# 2           jnardino                 NaN              0
# 3      heatherovieda                 NaN              0
# 4        ayeevickiee                 NaN              0
# ...              ...                 ...            ...
# 2995     willie_funk                 NaN              0
# 2996         csb2107                 NaN              0
# 2997   mwasserman818                 NaN              0
# 2998  MikeCunningham                 NaN              0
# 2999  kidith_paulino                 NaN              0
#
#                                                    text  \
# 0     @VirginAmerica it's really aggressive to blast...
# 1     @VirginAmerica and it's a really big bad thing...
# 2     @VirginAmerica seriously would pay $30 a fligh...
# 3     @VirginAmerica  I flew from NYC to SFO last we...
# 4     @VirginAmerica you guys messed up my seating.....
# ...                                                 ...
# 2995  @AmericanAir flights have been on time Late Fl...
# 2996  @AmericanAir yes called your UK number on skyp...
# 2997  @AmericanAir RDU Customer Service is awesome. ...
# 2998  @AmericanAir Always enjoy my time. Now on the ...
# 2999  @AmericanAir AA2416 on time and awesome flight...
#
#                       tweet_coord              tweet_created  \
# 0                             NaN  2015-02-24 11:15:36 -0800
# 1                             NaN  2015-02-24 11:14:45 -0800
# 2                             NaN  2015-02-24 11:14:33 -0800
# 3                             NaN  2015-02-24 09:39:46 -0800
# 4                             NaN  2015-02-24 08:18:51 -0800
# ...                           ...                        ...
# 2995                          NaN  2015-02-22 14:56:05 -0800
# 2996                          NaN  2015-02-22 14:38:02 -0800
# 2997  [35.87912533, -78.79162128]  2015-02-22 14:30:42 -0800
# 2998                          NaN  2015-02-22 14:22:47 -0800
# 2999  [25.79101279, -80.28861743]  2015-02-22 14:16:54 -0800
#
#              tweet_location                user_timezone  \
# 0                       NaN   Pacific Time (US & Canada)
# 1                       NaN   Pacific Time (US & Canada)
# 2                       NaN   Pacific Time (US & Canada)
# 3     this place called NYC   Eastern Time (US & Canada)
# 4                       714  Mountain Time (US & Canada)
# ...                     ...                          ...
# 2995          Dallas, Texas                          NaN
# 2996                    NaN                          NaN
# 2997  Flying Giraffe Travel   Pacific Time (US & Canada)
# 2998   Champaign/Urbana, IL                          NaN
# 2999                    NaN   Eastern Time (US & Canada)
#
#                                            sentence_bow  \
# 0     virginamerica really aggressive blast obnoxiou...
# 1                    virginamerica really big bad thing
# 2     virginamerica seriously would pay flight seats...
# 3     virginamerica flew nyc sfo last week could n't...
# 4     virginamerica guys messed seating reserved sea...
# ...                                                 ...
# 2995      americanair flights time late flightly though
# 2996  americanair yes called number skype…well worth...
# 2997  americanair rdu customer service awesome thank...
# 2998        americanair always enjoy time now plane dfw
# 2999  americanair aa2416 time awesome flight great j...
#
#                                        sentence_bow_lem  \
# 0     virginamerica really aggressive blast obnoxiou...
# 1                    virginamerica really big bad thing
# 2     virginamerica seriously would pay flight seat ...
# 3     virginamerica flew nyc sfo last week could n't...
# 4     virginamerica guy messed seating reserved seat...
# ...                                                 ...
# 2995       americanair flight time late flightly though
# 2996  americanair yes called number skype…well worth...
# 2997  americanair rdu customer service awesome thank...
# 2998        americanair always enjoy time now plane dfw
# 2999  americanair aa2416 time awesome flight great j...
#
#                                             sentence_dl
# 0     virginamerica it 's really aggressive to blast...
# 1     virginamerica and it 's a really big bad thing...
# 2     virginamerica seriously would pay $ 30 a fligh...
# 3     virginamerica i flew from nyc to sfo last week...
# 4     virginamerica you guys messed up my seating .....
# ...                                                 ...
# 2995  americanair flights have been on time late fli...
# 2996  americanair yes called your uk number on skype...
# 2997  americanair rdu customer service is awesome . ...
# 2998  americanair always enjoy my time . now on the ...
# 2999  americanair aa2416 on time and awesome flight ...
#
# [3000 rows x 19 columns]

# %%
l_cat = list(set(data_T['airline_sentiment']))
print("catégories : ", l_cat)
y_cat_num = [(1-l_cat.index(data_T.iloc[i]['airline_sentiment'])) for i in range(len(data_T))]
# Out:
# catégories :  ['positive', 'negative']

# %%
len(y_cat_num)
# Out:
# 3000

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

data_T['length_bow'] = data_T['sentence_bow'].apply(lambda x : len(word_tokenize(x)))
print("max length bow : ", data_T['length_bow'].max())
data_T['length_dl'] = data_T['sentence_dl'].apply(lambda x : len(word_tokenize(x)))
print("max length dl : ", data_T['length_dl'].max())
# Out:
# max length bow :  22
# max length dl :  42

# %%
l_cat
# Out:
# ['positive', 'negative']

# %% [markdown]
# ## Fonctions communes

# %%
import time

# Calcul Tsne, détermination des clusters et calcul ARI entre vrais catégorie et n° de clusters
def ARI_fct(features) :
    time1 = time.time()
    num_labels=len(l_cat)
    tsne = manifold.TSNE(n_components=2, perplexity=30, n_iter=2000, 
                                 init='random', learning_rate=200, random_state=42)
    X_tsne = tsne.fit_transform(features)
    
    # Détermination des clusters à partir des données après Tsne 
    cls = cluster.KMeans(n_clusters=num_labels, n_init=100, random_state=42)
    cls.fit(X_tsne)
    ARI = np.round(metrics.adjusted_rand_score(y_cat_num, cls.labels_),4)
    time2 = np.round(time.time() - time1,0)
    print("ARI : ", ARI, "time : ", time2)
    
    return ARI, X_tsne, cls.labels_


# visualisation du Tsne selon les vraies catégories et selon les clusters
def TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI) :
    fig = plt.figure(figsize=(15,6))
    
    ax = fig.add_subplot(121)
    scatter = ax.scatter(X_tsne[:,0],X_tsne[:,1], c=y_cat_num, cmap='Set1')
    ax.legend(handles=scatter.legend_elements()[0], labels=l_cat, loc="best", title="Categorie")
    plt.title('Représentation des tweets par catégories réelles')
    
    ax = fig.add_subplot(122)
    scatter = ax.scatter(X_tsne[:,0],X_tsne[:,1], c=labels, cmap='Set1')
    ax.legend(handles=scatter.legend_elements()[0], labels=set(labels), loc="best", title="Clusters")
    plt.title('Représentation des tweets par clusters')
    
    plt.show()
    print("ARI : ", ARI)

# %% [markdown]
# # Bag of word - Tf-idf

# %% [markdown]
# ## Préparation sentences

# %%
# création du bag of words (CountVectorizer et Tf-idf)

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

cvect = CountVectorizer(stop_words='english', max_df=0.95, min_df=1)
ctf = TfidfVectorizer(stop_words='english', max_df=0.95, min_df=1)

feat = 'sentence_bow_lem'
cv_fit = cvect.fit(data_T[feat])
ctf_fit = ctf.fit(data_T[feat])

cv_transform = cvect.transform(data_T[feat])  
ctf_transform = ctf.transform(data_T[feat])

# %% [markdown]
# ## Exécution des modèles

# %%
print("CountVectorizer : ")
print("-----------------")
ARI, X_tsne, labels = ARI_fct(cv_transform)
print()
print("Tf-idf : ")
print("--------")
ARI, X_tsne, labels = ARI_fct(ctf_transform)
# Out:
# CountVectorizer :
# -----------------
# ARI :  0.5318 time :  56.0
#
# Tf-idf :
# --------
# ARI :  0.5058 time :  49.0

# %% [markdown]
# ## Graphiques

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)
# Out:
# ARI :  0.5058

# %% [markdown]
# # Word2Vec

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
import gensim

# %% [markdown]
# ## Création du modèle Word2Vec

# %%
w2v_size=300
w2v_window=5
w2v_min_count=1
w2v_epochs=100
maxlen = 24 # adapt to length of sentences
sentences = data_T['sentence_bow_lem'].to_list()
sentences = [gensim.utils.simple_preprocess(text) for text in sentences]

# %%
# Création et entraînement du modèle Word2Vec

print("Build & train Word2Vec model ...")
w2v_model = gensim.models.Word2Vec(min_count=w2v_min_count, window=w2v_window,
                                                vector_size=w2v_size,
                                                seed=42,
                                                workers=1)
#                                                workers=multiprocessing.cpu_count())
w2v_model.build_vocab(sentences)
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=w2v_epochs)
model_vectors = w2v_model.wv
w2v_words = model_vectors.index_to_key
print("Vocabulary size: %i" % len(w2v_words))
print("Word2Vec trained")
# Out:
# Build & train Word2Vec model ...
# Vocabulary size: 4809
# Word2Vec trained

# %%
data_T['sentence_bow_lem']
# Out:
# 0       virginamerica really aggressive blast obnoxiou...
# 1                      virginamerica really big bad thing
# 2       virginamerica seriously would pay flight seat ...
# 3       virginamerica flew nyc sfo last week could n't...
# 4       virginamerica guy messed seating reserved seat...
#                               ...
# 2995         americanair flight time late flightly though
# 2996    americanair yes called number skype…well worth...
# 2997    americanair rdu customer service awesome thank...
# 2998          americanair always enjoy time now plane dfw
# 2999    americanair aa2416 time awesome flight great j...
# Name: sentence_bow_lem, Length: 3000, dtype: object

# %%
sentences
# Out:
# [['virginamerica',
#   'really',
#   'aggressive',
#   'blast',
#   'obnoxious',
#   'entertainment',
#   'guest',
#   'face',
#   'amp',
#   'little',
#   'recourse'],
#  ['virginamerica', 'really', 'big', 'bad', 'thing'],
#  ['virginamerica',
#   'seriously',
#   'would',
#   'pay',
#   'flight',
#   'seat',
#   'playing',
#   'really',
#   'bad',
#   'thing',
#   'flying'],
#  ['virginamerica',
#   'flew',
#   'nyc',
#   'sfo',
#   'last',
#   'week',
#   'could',
#   'fully',
#   'sit',
#   'seat',
#   'due',
#   'two',
#   'large',
#   'gentleman',
#   'either',
#   'side',
#   'help'],
#  ['virginamerica',
#   'guy',
#   'messed',
#   'seating',
#   'reserved',
#   'seating',
#   'friend',
#   'guy',
#   'gave',
#   'seat',
#   'away',
#   'want',
#   'free',
#   'internet'],
#  ['virginamerica',
#   'status',
#   'match',
#   'program',
#   'applied',
#   'three',
#   'week',
#   'called',
#   'emailed',
#   'response'],
#  ['virginamerica',
#   'what',
#   'happened',
#   'vegan',
#   'food',
#   'option',
#   'least',
#   'say',
#   'site',
#   'know',
#   'able',
#   'eat',
#   'anything',
#   'next',
#   'hr',
#   'fail'],
#  ['virginamerica',
#   'amazing',
#   'get',
#   'cold',
#   'air',
#   'vent',
#   'vx',
#   'noair',
#   'worstflightever',
#   'roasted',
#   'sfotobos'],
#  ['virginamerica',
#   'bked',
#   'cool',
#   'birthday',
#   'trip',
#   'add',
#   'elevate',
#   'cause',
#   'entered',
#   'middle',
#   'name',
#   'flight',
#   'booking',
#   'problem'],
#  ['virginamerica',
#   'help',
#   'left',
#   'expensive',
#   'headphone',
#   'flight',
#   'iad',
#   'lax',
#   'today',
#   'seat',
#   'one',
#   'answering',
#   'amp',
#   'number',
#   'lax'],
#  ['virginamerica',
#   'awaiting',
#   'return',
#   'phone',
#   'call',
#   'would',
#   'prefer',
#   'use',
#   'online',
#   'self',
#   'service',
#   'option'],
#  ['virginamerica',
#   'your',
#   'chat',
#   'support',
#   'working',
#   'site',
#   'co',
#   'vhp',
#   'gtdwpk'],
#  ['virginamerica',
#   'called',
#   'week',
#   'ago',
#   'adding',
#   'flight',
#   'elevate',
#   'still',
#   'shown',
#   'help'],
#  ['virginamerica',
#   'heyyyy',
#   'guyyyys',
#   'trying',
#   'get',
#   'hour',
#   'someone',
#   'call',
#   'please'],
#  ['virginamerica',
#   'virgin',
#   'hold',
#   'minute',
#   'earlier',
#   'flight',
#   'nyc',
#   'tonight',
#   'earlier',
#   'pm'],
#  ['virginamerica', 'everything', 'fine', 'lost', 'bag'],
#  ['virginamerica',
#   'airline',
#   'awesome',
#   'lax',
#   'loft',
#   'need',
#   'step',
#   'game',
#   'dirty',
#   'table',
#   'floor',
#   'co',
#   'hy',
#   'vrfhjht'],
#  ['virginamerica',
#   'going',
#   'customer',
#   'service',
#   'anyway',
#   'speak',
#   'human',
#   'asap',
#   'thank'],
#  ['virginamerica',
#   'supp',
#   'biz',
#   'traveler',
#   'like',
#   'southwestair',
#   'customer',
#   'service',
#   'like',
#   'jetblue'],
#  ['virginamerica',
#   'interesting',
#   'flying',
#   'cancelled',
#   'flight',
#   'next',
#   'four',
#   'flight',
#   'planned'],
#  ['virginamerica',
#   'disappointing',
#   'experience',
#   'shared',
#   'every',
#   'business',
#   'traveler',
#   'meet',
#   'neverflyvirgin'],
#  ['virginamerica',
#   'trouble',
#   'adding',
#   'flight',
#   'wife',
#   'booked',
#   'elevate',
#   'account',
#   'help',
#   'co',
#   'px',
#   'hqoks'],
#  ['virginamerica', 'why', 'site', 'when', 'back'],
#  ['virginamerica',
#   'like',
#   'interesting',
#   'video',
#   'just',
#   'disappointed',
#   'cancelled',
#   'flightled',
#   'flight',
#   'flight',
#   'went',
#   'jfk',
#   'saturday'],
#  ['virginamerica',
#   'landed',
#   'lax',
#   'hour',
#   'your',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'business',
#   'travel',
#   'friendly',
#   'nomorevirgin'],
#  ['virginamerica',
#   'website',
#   'btw',
#   'new',
#   'website',
#   'great',
#   'user',
#   'experience',
#   'time',
#   'another',
#   'redesign'],
#  ['virginamerica',
#   'check',
#   'add',
#   'bag',
#   'your',
#   'website',
#   'working',
#   've',
#   'tried',
#   'desktop',
#   'mobile',
#   'co',
#   'avyqdmpi'],
#  ['virginamerica',
#   'let',
#   'scanned',
#   'passenger',
#   'leave',
#   'plane',
#   'told',
#   'someone',
#   'remove',
#   'bag',
#   'st',
#   'class',
#   'bin',
#   'uncomfortable'],
#  ['virginamerica',
#   'what',
#   'phone',
#   'number',
#   'find',
#   'call',
#   'flight',
#   'reservation'],
#  ['virginamerica',
#   'anyone',
#   'anything',
#   'today',
#   'website',
#   'useless',
#   'one',
#   'answering',
#   'phone'],
#  ['virginamerica',
#   'must',
#   'traveler',
#   'miss',
#   'flight',
#   'late',
#   'flight',
#   'check',
#   'bag',
#   'missed',
#   'morning',
#   'appointment',
#   'lost',
#   'business',
#   'sfo',
#   'lax'],
#  ['virginamerica',
#   'late',
#   'flight',
#   'bag',
#   'check',
#   'lost',
#   'business',
#   'missed',
#   'flight',
#   'apt',
#   'three',
#   'people',
#   'flight',
#   'exp'],
#  ['virginamerica',
#   'called',
#   'service',
#   'line',
#   'hung',
#   'this',
#   'awesome',
#   'sarcasm'],
#  ['virginamerica',
#   'site',
#   'tripping',
#   'trying',
#   'check',
#   'getting',
#   'plain',
#   'text',
#   'version',
#   'reluctant',
#   'enter',
#   'card',
#   'info'],
#  ['virginamerica',
#   'concerned',
#   'fly',
#   'plane',
#   'need',
#   'delayed',
#   'due',
#   'tech',
#   'stop'],
#  ['virginamerica',
#   'and',
#   'flight',
#   'flight',
#   'booking',
#   'problem',
#   'site',
#   'totally',
#   'folk',
#   'problem'],
#  ['virginamerica',
#   'like',
#   'customer',
#   'service',
#   'min',
#   'delay',
#   'connecting',
#   'passenger',
#   'seems',
#   'long',
#   'va'],
#  ['virginamerica',
#   'failing',
#   'customer',
#   'check',
#   'process',
#   'link',
#   'tsa',
#   'pre',
#   'check'],
#  ['virginamerica',
#   'fidifamilies',
#   'terrible',
#   'airline',
#   'just',
#   'gave',
#   'hotel',
#   'hotline',
#   'number',
#   'said',
#   'sorry'],
#  ['virginamerica',
#   'chrysichrysic',
#   'assistance',
#   'yesterday',
#   'cancelled',
#   'flightled',
#   'flight',
#   'give',
#   'hotel',
#   'hotline',
#   'shame'],
#  ['virginamerica', 'another', 'delayed', 'flight'],
#  ['virginamerica',
#   'need',
#   'register',
#   'service',
#   'dog',
#   'first',
#   'class',
#   'ticket',
#   'sfo',
#   'dulles',
#   'the',
#   'phone',
#   'queue',
#   'hour',
#   'longer',
#   'pls',
#   'advise'],
#  ['virginamerica',
#   'book',
#   'seat',
#   'flight',
#   'buy',
#   'even',
#   'check',
#   'creates',
#   'much',
#   'anxiety',
#   'frustrated'],
#  ['virginamerica',
#   'paid',
#   'premium',
#   'fly',
#   'across',
#   'country',
#   'cancelled',
#   'flight',
#   'flight',
#   'offer',
#   'check',
#   'fee',
#   'upgrade',
#   'love',
#   'sad',
#   'face'],
#  ['virginamerica',
#   'understand',
#   'need',
#   'give',
#   'answer',
#   'damaged',
#   'luggage',
#   'policy'],
#  ['virginamerica', 'mean', 'policy', 'destroyed', 'luggage'],
#  ['virginamerica',
#   'problem',
#   'flight',
#   'booking',
#   'problem',
#   'web',
#   'site',
#   'keep',
#   'giving',
#   'error',
#   'contact',
#   'phone',
#   'phone',
#   'minute',
#   'wait'],
#  ['virginamerica',
#   'rang',
#   'wait',
#   'minute',
#   'book',
#   'ticket',
#   'vendor',
#   'fix',
#   'site'],
#  ['virginamerica',
#   'got',
#   'flight',
#   'told',
#   'today',
#   'checked',
#   'email',
#   'tomorrow',
#   'this',
#   'unacceptable'],
#  ['virginamerica',
#   'flight',
#   'lga',
#   'cancelled',
#   'flighted',
#   're',
#   'stuck',
#   'dallas',
#   'called',
#   'reschedule',
#   'told',
#   'could',
#   'get',
#   'flight',
#   'today'],
#  ['virginamerica',
#   'pairing',
#   'include',
#   'red',
#   'wine',
#   'only',
#   'white',
#   'offered',
#   'redwineisbetter'],
#  ['virginamerica',
#   'disappointed',
#   'agent',
#   'designated',
#   'silver',
#   'status',
#   'check',
#   'line',
#   'dulles_airport',
#   'closed',
#   'assist',
#   'pasengers'],
#  ['virginamerica',
#   'normal',
#   'receive',
#   'reply',
#   'central',
#   'baggage',
#   'baggageissues',
#   'smh'],
#  ['virginamerica',
#   'logan',
#   'airport',
#   'waiting',
#   'checkin',
#   'am',
#   'flight',
#   'checkin',
#   'desk',
#   'open',
#   'why'],
#  ['virginamerica',
#   'congrats',
#   'got',
#   'business',
#   'ewr',
#   'sfo',
#   'lax',
#   'fuck',
#   'united',
#   'fl',
#   'sfo',
#   'ewr',
#   'clincher'],
#  ['virginamerica',
#   'applied',
#   'week',
#   'ago',
#   'have',
#   'heard',
#   'back',
#   'flying',
#   'week',
#   'disappointed'],
#  ['virginamerica',
#   'many',
#   'apology',
#   'you',
#   'worse',
#   'airline',
#   'even',
#   'respond',
#   'cudtomers'],
#  ['virginamerica',
#   'shame',
#   'making',
#   'people',
#   'spend',
#   'money',
#   'stranded',
#   'city',
#   'airline',
#   'landing',
#   'jfk',
#   'who',
#   'reimburse'],
#  ['virginamerica',
#   'bad',
#   'say',
#   'take',
#   'day',
#   'via',
#   'your',
#   'confirmation',
#   'email',
#   'when',
#   'inquired',
#   'week',
#   'claim',
#   'week'],
#  ['virginamerica',
#   'lot',
#   'apology',
#   'thrown',
#   'customer',
#   'see',
#   'very',
#   'sad',
#   'thanks',
#   'nothing',
#   'worst',
#   'airline',
#   'ever'],
#  ['virginamerica',
#   'flight',
#   'stuff',
#   'wrong',
#   'nothing',
#   'had',
#   'worst',
#   'flight',
#   'ever'],
#  ['virginamerica',
#   'trying',
#   'book',
#   'flight',
#   'guy',
#   'website',
#   'let',
#   'lose',
#   'business'],
#  ['virginamerica', 'suck'],
#  ['virginamerica', 'just', 'same', 'issue', 'persisting'],
#  ['virginamerica',
#   'because',
#   'never',
#   'rec',
#   'cancelled',
#   'flightlation',
#   'notice',
#   'left',
#   'option',
#   'fly',
#   'driving',
#   'red',
#   'eye',
#   'mon',
#   'kid'],
#  ['virginamerica', 'trying', 'book', 'flight', 'amp', 'site'],
#  ['virginamerica',
#   'stink',
#   'flight',
#   'cancelled',
#   'flighted',
#   'psp',
#   'jfk',
#   'notification',
#   'ability',
#   'rebook',
#   'disappointed',
#   'expected',
#   'better'],
#  ['virginamerica', 'your', 'website', 'trying', 'check'],
#  ['virginamerica',
#   'flight',
#   'delayed',
#   'hour',
#   'due',
#   'mechanical',
#   'problem',
#   'handle',
#   'like',
#   'pro',
#   'could',
#   'tossed',
#   'free',
#   'drink'],
#  ['virginamerica',
#   'you',
#   'guy',
#   'charged',
#   'reschedule',
#   'flight',
#   'cancelled',
#   'flighted',
#   'refusing',
#   'refund',
#   'what',
#   'deal'],
#  ['virginamerica',
#   'access',
#   'website',
#   'safari',
#   'iphone',
#   'seems',
#   'work',
#   'mac',
#   'ipad',
#   'need',
#   'iphone',
#   'add',
#   'passbook'],
#  ['virginamerica',
#   'cancelled',
#   'flight',
#   'flight',
#   'vx',
#   'one',
#   'sec',
#   'delayed',
#   'airport',
#   'next',
#   'cancelled',
#   'flightled',
#   'gon',
#   'email',
#   'call',
#   'reschedule'],
#  ['virginamerica', 'problem', 'link', 'email', 'check', 'thanks'],
#  ['virginamerica',
#   'change',
#   'another',
#   'airline',
#   'get',
#   'today',
#   'why',
#   'united',
#   'able',
#   'land',
#   'cost',
#   'ugh'],
#  ['virginamerica',
#   'looking',
#   'forward',
#   'first',
#   'flight',
#   'today',
#   'cancelled',
#   'flightled',
#   'along',
#   'subsequent',
#   'one'],
#  ['virginamerica', 'gon', 'deal', 'dallas', 'deal', 'dallas', 'sad'],
#  ['virginamerica', 'hold', 'time', 'call', 'center', 'bit', 'much'],
#  ['virginamerica', 'cs', 'site', 'right', 'please', 'fix', 'site', 'unusable'],
#  ['virginamerica',
#   'current',
#   'bug',
#   'website',
#   'show',
#   'select',
#   'departure',
#   'city',
#   'selecting',
#   'destination',
#   'city',
#   'co',
#   'sllyibe',
#   'vq'],
#  ['virginamerica',
#   'luggage',
#   'severely',
#   'dented',
#   'missing',
#   'wheel',
#   'coming',
#   'baggage',
#   'claim',
#   'san',
#   'luggage',
#   'agent',
#   'miranda',
#   'think',
#   'help'],
#  ['virginamerica',
#   'requested',
#   'window',
#   'seat',
#   'confirmed',
#   'window',
#   'got',
#   'stuck',
#   'middle',
#   'seat',
#   'not',
#   'good',
#   'way',
#   'treat',
#   'silver',
#   'member'],
#  ['virginamerica', 'something', 'wrong', 'website', 'safari', 'iphone'],
#  ['virginamerica',
#   'boo',
#   'refunding',
#   'seat',
#   'upgrade',
#   'fee',
#   'want',
#   'buy',
#   'first',
#   'place'],
#  ['virginamerica',
#   'moved',
#   'seat',
#   'notice',
#   'better',
#   'seat',
#   'cabin',
#   'select',
#   'behind',
#   'row',
#   'selected',
#   'disappointed'],
#  ['virginamerica',
#   'already',
#   'contacted',
#   'central',
#   'baggage',
#   'amp',
#   'sent',
#   'renttherunway',
#   'charging',
#   'dress',
#   'lost',
#   'suitcase',
#   'help'],
#  ['virginamerica',
#   'virginatlantic',
#   'checked',
#   'flight',
#   'sfo',
#   'lax',
#   'amp',
#   'told',
#   'atlantic',
#   'flying',
#   'club',
#   'gold',
#   'get',
#   'benefit'],
#  ['virginamerica',
#   'husband',
#   'ordered',
#   'three',
#   'drink',
#   'via',
#   'screen',
#   'never',
#   'came',
#   'awesome'],
#  ['virginamerica',
#   'soooo',
#   'guy',
#   'going',
#   'leave',
#   'seatbelt',
#   'light',
#   'flight',
#   'you',
#   'barely',
#   'call',
#   'turbulence'],
#  ['virginamerica',
#   'funny',
#   'story',
#   'website',
#   'broken',
#   'missing',
#   'javascript',
#   'stylesheets',
#   'checkin',
#   'process',
#   'dislike'],
#  ['virginamerica',
#   'trying',
#   'check',
#   'am',
#   'flight',
#   'tmm',
#   'desktop',
#   'website',
#   'working',
#   'sort',
#   'caching',
#   'bug',
#   'so'],
#  ['virginamerica',
#   'guy',
#   'know',
#   'check',
#   'link',
#   'email',
#   'broken',
#   'co',
#   'npxb',
#   'obmr'],
#  ['virginamerica',
#   'lost',
#   'luggage',
#   'day',
#   'ago',
#   'flight',
#   'lax',
#   'iad',
#   'amp',
#   'calling',
#   'every',
#   'day',
#   'response',
#   'please',
#   'give',
#   'back',
#   'stuff'],
#  ['virginamerica',
#   'look',
#   'like',
#   'broken',
#   'link',
#   'asset',
#   'co',
#   'oardjjgrrd'],
#  ['virginamerica',
#   'manage',
#   'itinerary',
#   'section',
#   'website',
#   'seems',
#   'broken',
#   'co',
#   'pujvcelng'],
#  ['virginamerica',
#   'check',
#   'site',
#   'look',
#   'like',
#   'every',
#   'time',
#   'load',
#   'co',
#   'kacy',
#   'awdbw'],
#  ['virginamerica',
#   'other',
#   'carrier',
#   'le',
#   'half',
#   'price',
#   'round',
#   'trip',
#   'fare',
#   'stunned',
#   'co',
#   'ukdjjijrow'],
#  ['virginamerica',
#   'wtf',
#   'happening',
#   'pdx',
#   'late',
#   'flight',
#   'march',
#   'one',
#   'way',
#   'sfo'],
#  ['virginamerica',
#   'luggage',
#   'gone',
#   've',
#   'filed',
#   'paperwork',
#   'promised',
#   'call',
#   'email',
#   'still',
#   'resolution',
#   'response',
#   'central',
#   'luggage'],
#  ['virginamerica',
#   'requested',
#   'mileage',
#   'challenge',
#   'status',
#   'several',
#   'week',
#   'ago',
#   'online',
#   'heard',
#   'back',
#   'how',
#   'get',
#   'help'],
#  ['virginamerica',
#   'applied',
#   'status',
#   'match',
#   'feb',
#   'got',
#   'confirmation',
#   'email',
#   'day',
#   'still',
#   'news',
#   'though',
#   'you',
#   'guy',
#   'dropped',
#   'ball',
#   'late',
#   'flightly'],
#  ['virginamerica',
#   'really',
#   'experience',
#   'hoping',
#   'forced',
#   'check',
#   'small',
#   'carry',
#   'nothing',
#   'empty',
#   'cabin',
#   'space',
#   'board'],
#  ['virginamerica',
#   'spoke',
#   'representative',
#   'offered',
#   'solution',
#   'loyal',
#   'customer',
#   'fly',
#   'virginatlantic',
#   'well'],
#  ['virginamerica',
#   'deeply',
#   'disappointed',
#   'birthday',
#   'promo',
#   'applied',
#   'trip',
#   'booked',
#   'mere',
#   'day',
#   'received',
#   'email'],
#  ['virginamerica', 'vx', 'jfk', 'dirty', 'plane', 'standard'],
#  ['virginamerica',
#   'flight',
#   'vx',
#   'headed',
#   'jfk',
#   'dirtiest',
#   'plane',
#   'ever',
#   'sad',
#   'great',
#   'airline'],
#  ['virginamerica',
#   'avis',
#   'rental',
#   'continue',
#   'button',
#   'work',
#   'website',
#   'book',
#   'car',
#   'tried',
#   'time',
#   'phone',
#   'this',
#   'suck'],
#  ['virginamerica', 'delayed', 'to'],
#  ['virginamerica',
#   'currently',
#   'minute',
#   'hold',
#   'cust',
#   'service',
#   'need',
#   'anything',
#   'add',
#   'lap',
#   'child',
#   'reservation'],
#  ['virginamerica',
#   'comenity',
#   'bank',
#   'joke',
#   'please',
#   'change',
#   'nothing',
#   'constant',
#   'problem',
#   'bank'],
#  ['virginamerica',
#   'submitted',
#   'status',
#   'match',
#   'request',
#   'back',
#   'still',
#   'heard',
#   'flying',
#   'monday',
#   'can',
#   'look',
#   'accelerate'],
#  ['virginamerica', 'even', 'open', 'laptop', 'seat', 'paid', 'premium', 'let'],
#  ['virginamerica', 'seat', 'even', 'open', 'laptop', 'paid', 'extra', 'seat'],
#  ['virginamerica',
#   'status',
#   'match',
#   'week',
#   'gone',
#   'news',
#   'flt',
#   'next',
#   'week',
#   'hope',
#   'flt',
#   'count',
#   'towards',
#   'requirement',
#   'cust',
#   'svc',
#   'help'],
#  ['virginamerica',
#   'come',
#   'iphone',
#   'app',
#   'still',
#   'using',
#   'making',
#   'waste',
#   'paper'],
#  ['virginamerica',
#   'your',
#   'back',
#   'seat',
#   'entertainment',
#   'system',
#   'accept',
#   'credit',
#   'card',
#   'apostrophe',
#   'surname',
#   'apostrophefail'],
#  ['virginamerica',
#   'kinda',
#   'sucked',
#   'earphone',
#   'jack',
#   'work',
#   'flight',
#   'they',
#   'may',
#   'want',
#   'look',
#   'future',
#   'passenger'],
#  ['virginamerica',
#   'very',
#   'poor',
#   'experience',
#   'first',
#   'computer',
#   'problem',
#   'seat',
#   'malfunction',
#   'stuck',
#   'missing',
#   'meeting',
#   'san',
#   'diego'],
#  ['virginamerica',
#   'tried',
#   'you',
#   'offered',
#   'charge',
#   'additional',
#   'new',
#   'ticket',
#   'stranded',
#   'thurs',
#   'st',
#   'time',
#   'last',
#   'time'],
#  ['virginamerica',
#   'never',
#   'bad',
#   'experience',
#   'one',
#   'took',
#   'cake',
#   'now',
#   'extortion',
#   'carry',
#   'item',
#   'well'],
#  ['virginamerica',
#   'had',
#   'spend',
#   'hour',
#   'worrying',
#   'item',
#   'carryon',
#   'would',
#   'broken',
#   'stolen',
#   'since',
#   'could',
#   'carry',
#   'plane',
#   'lock',
#   'bag'],
#  ['virginamerica',
#   'all',
#   'group',
#   'told',
#   'room',
#   'bin',
#   'got',
#   'plane',
#   'room',
#   'least',
#   'bag',
#   'row'],
#  ['virginamerica',
#   'lot',
#   'flight',
#   'book',
#   'site',
#   'working',
#   've',
#   'phone',
#   'waiting',
#   'minute'],
#  ['virginamerica',
#   'why',
#   'taking',
#   'year',
#   'fly',
#   'home',
#   'dallas',
#   'get',
#   'shit',
#   'together'],
#  ['virginamerica', 'man', 'steel', 'fly', 'city', 'though', 'frequency'],
#  ['virginamerica',
#   'started',
#   'flight',
#   'scolding',
#   'using',
#   'overhead',
#   'bin',
#   'offered',
#   'person',
#   'seated',
#   'next'],
#  ['virginamerica',
#   'while',
#   'airline',
#   'cancelled',
#   'flighting',
#   'flight',
#   'bos',
#   'helping',
#   'customer',
#   'get',
#   'home',
#   'virgin',
#   'saying',
#   'good',
#   'luck'],
#  ['virginamerica',
#   'grouping',
#   'virgin',
#   'others',
#   'bos',
#   'weather',
#   'exposed',
#   'actual',
#   'cu',
#   'serv',
#   'model',
#   'never',
#   'flight',
#   'booking',
#   'problem',
#   'virgin'],
#  ['virginamerica',
#   'one',
#   'traveler',
#   'affected',
#   'boston',
#   'storm',
#   'shocked',
#   'virgin',
#   'complete',
#   'apathy',
#   'toward',
#   'customer'],
#  ['virginamerica',
#   'group',
#   'got',
#   'cancelled',
#   'flightlation',
#   'fee',
#   'waived',
#   'ticket',
#   'booked',
#   'your',
#   'rep',
#   'help',
#   'either'],
#  ['united',
#   'still',
#   'refund',
#   'word',
#   'via',
#   'please',
#   'resolve',
#   'issue',
#   'cancelled',
#   'flightled',
#   'flight',
#   'useless',
#   'assistant',
#   'trip'],
#  ['united',
#   'delayed',
#   'due',
#   'lack',
#   'crew',
#   'delayed',
#   'long',
#   'line',
#   'deicing',
#   'still',
#   'need',
#   'improve',
#   'service',
#   'united'],
#  ['united',
#   'worst',
#   'nonrefundable',
#   'first',
#   'class',
#   'ticket',
#   'select',
#   'global',
#   'system',
#   'auto',
#   'selects',
#   'economy',
#   'upgrade'],
#  ['united',
#   'cheertymedad',
#   'buy',
#   'tix',
#   'day',
#   'flight',
#   'transfer',
#   'tix',
#   'flawed',
#   'security',
#   'logic',
#   'flawed',
#   'customer',
#   'service'],
#  ['united',
#   'car',
#   'seat',
#   'lost',
#   'united',
#   'reimburse',
#   'new',
#   'one',
#   'pair',
#   'shoe',
#   'necessity',
#   'child'],
#  ['united',
#   'beginning',
#   'feb',
#   'called',
#   'united',
#   'said',
#   'would',
#   'send',
#   'another',
#   'voucher',
#   'mail',
#   'never',
#   'got',
#   'anything',
#   'tiredofwaiting'],
#  ['united',
#   'internet',
#   'great',
#   'thing',
#   'emailing',
#   'executive',
#   'company',
#   'maybe',
#   'respond',
#   'timely',
#   'manner'],
#  ['united', 'thats', 'weak', 'see', 'hey', 'virginamerica'],
#  ['united',
#   'flew',
#   'back',
#   'company',
#   'since',
#   'united',
#   'didnt',
#   'earlier',
#   'flight'],
#  ['united',
#   'trying',
#   'book',
#   'award',
#   'september',
#   'need',
#   'flight',
#   'aegeanairlines',
#   'show',
#   'even',
#   'many',
#   'award',
#   'seat',
#   'availab'],
#  ['united',
#   'sure',
#   'drive',
#   'total',
#   'hour',
#   'get',
#   'bag',
#   'like',
#   'explain',
#   'debacle',
#   'one',
#   'want',
#   'talk'],
#  ['united',
#   'see',
#   'told',
#   'repeatedly',
#   'pilot',
#   'late',
#   'flight',
#   'kept',
#   'getting',
#   'late',
#   'flightr',
#   'after',
#   'boarded',
#   'defibrillator',
#   'issue'],
#  ['united',
#   'preferred',
#   'security',
#   'line',
#   'anymore',
#   'tsa',
#   'pre',
#   'check',
#   'pull',
#   'silverairways',
#   'partner',
#   'flight',
#   'platinum',
#   'spoiled'],
#  ['united',
#   'how',
#   'united',
#   'refuse',
#   'reissue',
#   'lost',
#   'voucher',
#   'plane',
#   'take',
#   'due',
#   'mechanic'],
#  ['united',
#   'yes',
#   've',
#   'agent',
#   'last',
#   'minute',
#   'one',
#   'agent',
#   'rude',
#   'thankfully',
#   'ladan',
#   'nice'],
#  ['united',
#   'iah',
#   'charlotte',
#   'baggage',
#   'claim',
#   'rep',
#   'latrice',
#   'customerservice',
#   'non',
#   'existent',
#   'ignored',
#   'customer',
#   'inappropriately',
#   'touched',
#   'customer'],
#  ['united',
#   'uctraveladvisor',
#   'would',
#   'loved',
#   'respond',
#   'website',
#   'saw',
#   'really',
#   'long',
#   'form',
#   'business',
#   'new',
#   'seat',
#   'bad'],
#  ['united',
#   'refund',
#   'flight',
#   'voucher',
#   'another',
#   'flight',
#   'different',
#   'airline',
#   'expense',
#   'today',
#   'hour',
#   'drive',
#   'inconvenient'],
#  ['united',
#   'received',
#   'call',
#   'back',
#   'day',
#   'infant',
#   'car',
#   'seat',
#   'supposed',
#   'anywhere',
#   'child'],
#  ['united',
#   'well',
#   'sitting',
#   'ground',
#   'on',
#   'time',
#   'waiting',
#   'gate',
#   'tiredofthis'],
#  ['united',
#   'need',
#   'guy',
#   'book',
#   'plane',
#   'concern',
#   'll',
#   'travel',
#   'someone',
#   'else',
#   'moving',
#   'forward'],
#  ['united',
#   'measly',
#   'certificate',
#   'appreciate',
#   'loyal',
#   'customer',
#   'wait',
#   'hrs',
#   'tarmac',
#   'ua',
#   'unacceptable'],
#  ['united', 'rude', 'rude'],
#  ['united',
#   'why',
#   'get',
#   'boarding',
#   'pas',
#   'austrian',
#   'airline',
#   'codeshare',
#   'flight',
#   'rebook',
#   'incls',
#   'hour',
#   'layover',
#   'amp',
#   'stuck',
#   'outside',
#   'sec'],
#  ['united',
#   'flew',
#   'telaviv',
#   'paid',
#   'third',
#   'suitcase',
#   'even',
#   'make',
#   'plane',
#   'besides',
#   'impolite',
#   'service'],
#  ['united',
#   'bag',
#   'still',
#   'colo',
#   'spring',
#   'disabled',
#   'search',
#   'unfamiliar',
#   'airport',
#   'look',
#   'bag',
#   'not',
#   'good',
#   'outcome'],
#  ['united',
#   'shame',
#   'flex',
#   'ticket',
#   'transfer',
#   'rule',
#   'even',
#   'calling',
#   'neurosurgery',
#   'icu',
#   'enough'],
#  ['united',
#   'denver',
#   'said',
#   'handle',
#   'baggage',
#   'made',
#   'colo',
#   'spring',
#   'they',
#   'gave',
#   'number',
#   'call',
#   'help',
#   'either'],
#  ['united',
#   'guy',
#   'need',
#   'serious',
#   'training',
#   'customer',
#   'service',
#   'too',
#   'many',
#   'better',
#   'option',
#   'put',
#   'way',
#   'guy',
#   'handle',
#   'mistake'],
#  ['united',
#   'found',
#   'problem',
#   'avoided',
#   'like',
#   'plague',
#   'wa',
#   'told',
#   'find',
#   'supervisor'],
#  ['united',
#   'zcc',
#   'cancelled',
#   'flight',
#   'flight',
#   'advance',
#   'need',
#   'connect',
#   'flight',
#   'reschedule',
#   'link',
#   'helping',
#   'help',
#   'waited',
#   'month',
#   'see'],
#  ['united', 'flying'],
#  ['united',
#   'addition',
#   'first',
#   'flight',
#   'delayed',
#   'hour',
#   'arriving',
#   'destination',
#   'hr',
#   'late',
#   'flight'],
#  ['united',
#   'upset',
#   'disability',
#   'service',
#   'when',
#   'told',
#   'one',
#   'employee',
#   'carrying',
#   'medical',
#   'equipment',
#   'rude'],
#  ['united',
#   'thnx',
#   'quick',
#   'reply',
#   'think',
#   'assist',
#   'our',
#   'intl',
#   'grp',
#   'put',
#   'considerable',
#   'inconvenience',
#   'today'],
#  ['united',
#   'wont',
#   'transfer',
#   'flight',
#   'ticket',
#   'accompany',
#   'old',
#   'active',
#   'military',
#   'mom',
#   'emergency',
#   'brain',
#   'surgery',
#   'wow'],
#  ['united',
#   'getmeontop',
#   'week',
#   'late',
#   'flightr',
#   'and',
#   'still',
#   'have',
#   'not',
#   'received',
#   'mile',
#   'from',
#   'the',
#   'mileageplus',
#   'gift',
#   'card',
#   'starbucks',
#   'card',
#   'handed',
#   'over'],
#  ['united',
#   'yet',
#   'complained',
#   'guy',
#   'checked',
#   'luggage',
#   'throwing',
#   'bag',
#   'around',
#   'unfortunate',
#   'coincidence',
#   'hope'],
#  ['united',
#   'okc',
#   'ticket',
#   'agent',
#   'roger',
#   'mclarren',
#   'le',
#   'helpful',
#   'intl',
#   'group',
#   'travel',
#   'problem',
#   'find',
#   'supervisor',
#   'help'],
#  ['united',
#   'another',
#   'fail',
#   'united',
#   'ticket',
#   'agent',
#   'okc',
#   'le',
#   'helpful',
#   'could',
#   'care',
#   'le',
#   'problem',
#   'american',
#   'come'],
#  ['united',
#   'sent',
#   'email',
#   'customer',
#   'care',
#   'telling',
#   'may',
#   'break',
#   'sincerely',
#   'hope',
#   'help'],
#  ['united',
#   'silly',
#   'flying',
#   'delta',
#   'today',
#   'your',
#   'united',
#   'club',
#   'staff',
#   'attendant',
#   'surly',
#   'unhelpful',
#   'always',
#   'seem',
#   'bothered',
#   'pesky',
#   'folk'],
#  ['united',
#   'well',
#   'fix',
#   'missing',
#   'buddy',
#   'th',
#   'bday',
#   'negligence',
#   'attempt',
#   'make'],
#  ['united',
#   'believe',
#   'help',
#   'customer',
#   'service',
#   'could',
#   'like',
#   'said',
#   'want',
#   'number',
#   'someone',
#   'fix'],
#  ['united',
#   'point',
#   'asking',
#   'detail',
#   'servicedog',
#   'book',
#   'flight',
#   'crew',
#   'read',
#   'continued'],
#  ['united',
#   'tried',
#   'one',
#   'available',
#   'bogota',
#   'everyone',
#   'rude',
#   'houston',
#   'stuck',
#   'hour',
#   'guy'],
#  ['united',
#   'worst',
#   'la',
#   'iad',
#   'mechanical',
#   'problem',
#   'took',
#   'land',
#   'fix',
#   'delayed',
#   'wtfodds'],
#  ['united',
#   'what',
#   'going',
#   'outbound',
#   'flight',
#   'last',
#   'thurs',
#   'delayed',
#   'hrs',
#   'how',
#   'long',
#   'delay',
#   'worst'],
#  ['united',
#   'worst',
#   'ua',
#   'iad',
#   'la',
#   'mechanical',
#   'problem',
#   'switched',
#   'aircraft',
#   'delayed',
#   'hour'],
#  ['united', 'crashed', 'trying', 'check'],
#  ['united',
#   'logan',
#   'boarding',
#   'gong',
#   'show',
#   'due',
#   'lax',
#   'carry',
#   'enforcement',
#   'bin',
#   'full',
#   'coat',
#   'room',
#   'bag',
#   'need',
#   'better',
#   'system'],
#  ['united',
#   'blackmailed',
#   'paying',
#   'extra',
#   'return',
#   'ticket',
#   'nullified',
#   'san',
#   'francisco',
#   'airport',
#   'terrible',
#   'service',
#   'rep',
#   'scam'],
#  ['united',
#   'disappointed',
#   'didnt',
#   'honor',
#   'credit',
#   'given',
#   'mistake',
#   'taking',
#   'business',
#   'elsewhere',
#   'out'],
#  ['united', 'ua', 'still', 'waiting', 'supposed', 'depart'],
#  ['united',
#   'month',
#   'waiting',
#   'hear',
#   'airline',
#   'gave',
#   'quite',
#   'bit',
#   'day',
#   'requested',
#   'terrible',
#   'service'],
#  ['united',
#   'process',
#   'ever',
#   'end',
#   'still',
#   'waiting',
#   'reply',
#   'since',
#   'month',
#   'pathetic',
#   'customerservice'],
#  ['united',
#   'what',
#   'going',
#   'website',
#   'flight',
#   'booking',
#   'problem',
#   'three',
#   'ticket',
#   'today',
#   've',
#   'booted',
#   'system',
#   'umpteen',
#   'time'],
#  ['united',
#   'get',
#   'account',
#   'number',
#   'website',
#   'say',
#   'email',
#   'unavailable'],
#  ['united', 'received', 'bag', 'last', 'night', 'still', 'missing', 'one'],
#  ['united',
#   'simonroesner',
#   'll',
#   'need',
#   'upgrade',
#   'seat',
#   'even',
#   'economy',
#   'plus',
#   'like',
#   'sitting',
#   'concrete',
#   'bench'],
#  ['united',
#   'nd',
#   'flight',
#   'also',
#   'delayed',
#   'pilot',
#   'but',
#   'boarded',
#   'sit',
#   'scheduling'],
#  ['united',
#   'way',
#   'simple',
#   'apology',
#   'go',
#   'long',
#   'way',
#   'even',
#   'hollow',
#   'one',
#   'obvious',
#   'care',
#   'well'],
#  ['united',
#   'this',
#   'one',
#   'time',
#   'thing',
#   'either',
#   'shocking',
#   'pattern',
#   'repeated',
#   'neglect',
#   'disrespect'],
#  ['united',
#   'finger',
#   'crossed',
#   'amp',
#   'intact',
#   'very',
#   'disappointed',
#   'experience',
#   'actually',
#   'saying',
#   'enjoyed',
#   'using'],
#  ['united',
#   'incredibly',
#   'easy',
#   'fix',
#   'would',
#   'rather',
#   'stay',
#   'comfort',
#   'zone',
#   'get',
#   'forced',
#   'mine'],
#  ['united',
#   'july',
#   'you',
#   'zero',
#   'excuse',
#   'you',
#   'date',
#   'system',
#   'cause',
#   'problem',
#   'like'],
#  ['united',
#   'everyone',
#   'around',
#   'sitting',
#   'friend',
#   'family',
#   'member',
#   'they',
#   'booked',
#   'ticket',
#   'october',
#   'december',
#   'bought'],
#  ['united', 'moving', 'americanair', 'united', 'talk', 'service'],
#  ['united',
#   'asked',
#   'legitimate',
#   'question',
#   'systemwide',
#   'vs',
#   'localized',
#   'problem',
#   'got',
#   'back',
#   'unrelate',
#   'flightd',
#   'copy',
#   'paste',
#   'you',
#   'better'],
#  ['united',
#   'time',
#   'who',
#   'call',
#   'need',
#   'ski',
#   'airport',
#   'get',
#   'faith',
#   'united'],
#  ['united',
#   'maybe',
#   'bbbne_sd_ks_ia',
#   'would',
#   'care',
#   'hear',
#   'went',
#   'whoever',
#   'listens',
#   'issue',
#   'caused'],
#  ['united',
#   're',
#   'telling',
#   'number',
#   'call',
#   'left',
#   'airport',
#   'negligent',
#   'pilot',
#   'staff'],
#  ['united', 'could', 'email', 'resent', 'doesnt', 'appear', 'arrived'],
#  ['united',
#   'united',
#   'coupon',
#   'make',
#   'broken',
#   'entertainment',
#   'system',
#   'hour',
#   'flight',
#   'seriously',
#   'ridiculousness'],
#  ['united',
#   'drop',
#   'bag',
#   'overnight',
#   'amp',
#   'leaving',
#   'week',
#   'this',
#   'supposed',
#   'hold',
#   'bag'],
#  ['united', 'detail', 'still', 'response', 'book', 'today'],
#  ['united', 'able', 'confirmation', 'number'],
#  ['united',
#   'unhappy',
#   'response',
#   'complaint',
#   'emailed',
#   'nd',
#   'feb',
#   'ref',
#   'awful',
#   'customer',
#   'service'],
#  ['united',
#   'common',
#   'keep',
#   'paper',
#   'work',
#   'ready',
#   'delay',
#   'flight',
#   'meeting',
#   'choosechicago'],
#  ['united', 'frustrated', 'nervous'],
#  ['united', 'one', 'make', 'difficult'],
#  ['united', 'get', 'cancelled', 'flightled', 'hour', 'take'],
#  ['united',
#   'this',
#   'always',
#   'happens',
#   'guy',
#   'make',
#   'traveling',
#   'incredibly',
#   'stressful',
#   'uncomfortable',
#   'good',
#   'business'],
#  ['united',
#   'seeking',
#   'client',
#   'cant',
#   'get',
#   'need',
#   'refund',
#   'filled',
#   'form',
#   'confident',
#   'work',
#   'past',
#   'indication'],
#  ['united',
#   'luckily',
#   'made',
#   'flight',
#   'time',
#   'disappointed',
#   'lack',
#   'communication'],
#  ['united',
#   'checking',
#   'see',
#   'flight',
#   'atl',
#   'ord',
#   'got',
#   'cancelled',
#   'flighted'],
#  ['united',
#   'service',
#   'far',
#   'horrid',
#   'wanted',
#   'end',
#   'trip',
#   'high',
#   'note',
#   'guess',
#   'option'],
#  ['united',
#   'booked',
#   'flight',
#   'home',
#   'month',
#   'ago',
#   'requested',
#   'seat',
#   'together',
#   'fiancée',
#   'got',
#   'middle',
#   'seat',
#   'unacceptable',
#   'the'],
#  ['united', 'you', 'guy', 'are', 'horrible'],
#  ['united',
#   'why',
#   'pay',
#   'wifi',
#   'international',
#   'business',
#   'ticket',
#   'pennypincher'],
#  ['united',
#   'ok',
#   'top',
#   'thing',
#   've',
#   'lost',
#   'luggage',
#   'could',
#   'get',
#   'any',
#   'worse',
#   'unitedairlines'],
#  ['united', 'and', 'luggage', 'broken', 'brokenwheel'],
#  ['united', 'maybe', 'one', 'day', 'll', 'one', 'quoted', 'co', 'mjkpgvxmpc'],
#  ['united',
#   'flight',
#   'delayed',
#   'one',
#   'remembered',
#   'turn',
#   'heat',
#   'flight',
#   'leaving',
#   'ord',
#   'seriously'],
#  ['united',
#   'speak',
#   'real',
#   'person',
#   'get',
#   'resolved',
#   'politely',
#   'efficiently'],
#  ['united',
#   'bag',
#   'make',
#   'flight',
#   'iad',
#   'second',
#   'day',
#   'without',
#   'clothes',
#   'pretty',
#   'inconvenient',
#   're',
#   'pretty',
#   'curious',
#   'unitedairlines'],
#  ['united',
#   'hence',
#   've',
#   'asking',
#   'customer',
#   'service',
#   'phone',
#   'number',
#   'speak',
#   'real',
#   'person',
#   'get',
#   'sorted'],
#  ['united',
#   'bag',
#   'leave',
#   'washington',
#   'yet',
#   'that',
#   'would',
#   'convenient',
#   'seeing',
#   'left',
#   'day',
#   'ago',
#   'unitedairlines',
#   'lostluggage'],
#  ['united',
#   'pls',
#   'properly',
#   'train',
#   'agent',
#   'requested',
#   'speak',
#   'customer',
#   'service',
#   'amp',
#   'transferred',
#   'dead',
#   'end',
#   'not',
#   'even',
#   'open'],
#  ['united',
#   'thanks',
#   'remembering',
#   'load',
#   'bag',
#   'onto',
#   'connecting',
#   'flight',
#   'wait',
#   'forgot',
#   'iceland',
#   'fun',
#   'clothes'],
#  ['united',
#   'customer',
#   'service',
#   'atrocious',
#   'you',
#   'disrupted',
#   'travel',
#   'plan',
#   'lost',
#   'luggage',
#   'impossible',
#   'talk',
#   'human'],
#  ['united',
#   'flight',
#   'now',
#   'currently',
#   'stuck',
#   'portland',
#   'missed',
#   'ride',
#   'hour',
#   'delay',
#   'getmartyhome'],
#  ['united',
#   'responded',
#   'various',
#   'request',
#   'contact',
#   'number',
#   'anyone',
#   'know',
#   'customer',
#   'service',
#   'number',
#   'unitedairlines'],
#  ['united',
#   'could',
#   'update',
#   'suitcase',
#   'please',
#   'the',
#   'online',
#   'phone',
#   'tracking',
#   'told',
#   'nothing',
#   'told',
#   'back',
#   'yesterday'],
#  ['united',
#   'last',
#   'thing',
#   'guy',
#   'charging',
#   'drink',
#   'transatlantic',
#   'flight'],
#  ['united',
#   'lhr',
#   'arrival',
#   'lounge',
#   'fail',
#   'waited',
#   'min',
#   'shower',
#   'left',
#   'find',
#   'hotel',
#   'know',
#   'many',
#   'passenger',
#   'carry',
#   'planning'],
#  ['united',
#   'completed',
#   'form',
#   'doubt',
#   'use',
#   'care',
#   'day',
#   'vacation',
#   'sure',
#   'feel',
#   'responsibility'],
#  ['united',
#   'nope',
#   'told',
#   'time',
#   'home',
#   'sleep',
#   'airport',
#   'even',
#   'though',
#   'assured',
#   'would',
#   'get',
#   'room'],
#  ['united',
#   'back',
#   'expensive',
#   'holiday',
#   'worked',
#   'year',
#   'pay',
#   'ruined',
#   'want',
#   'compensation',
#   'amp',
#   'original',
#   'case',
#   'back'],
#  ['united',
#   'thanks',
#   'united',
#   'understand',
#   'but',
#   'would',
#   'actually',
#   'like',
#   'bag',
#   'back',
#   'what',
#   'done',
#   'also',
#   'want',
#   'money'],
#  ['united',
#   'frankly',
#   'worse',
#   'customer',
#   'service',
#   'ever',
#   'problem',
#   'happen',
#   'deal',
#   'defines',
#   'company',
#   'never',
#   'united'],
#  ['united',
#   'still',
#   'valid',
#   'flight',
#   'just',
#   'seems',
#   'strange',
#   'delay',
#   'late',
#   'flight',
#   'inbound',
#   'crew',
#   'hour',
#   'plane',
#   'already'],
#  ['united', 'thanks', 'lack', 'help', 'canned', 'response', 'desk'],
#  ['united',
#   'bad',
#   'another',
#   'unforeseeable',
#   'operational',
#   'issue',
#   'return',
#   'flight'],
#  ['united',
#   'pay',
#   'luggage',
#   'delivered',
#   'arrive',
#   'why',
#   'wait',
#   'additional',
#   'day',
#   'delivery'],
#  ['united',
#   'hotel',
#   'people',
#   'feel',
#   'like',
#   'held',
#   'hostage',
#   'someone',
#   'boarding',
#   'pass',
#   'leave',
#   'fail'],
#  ['united',
#   'outbound',
#   'bag',
#   'lb',
#   'bag',
#   'returning',
#   'home',
#   'bag',
#   'lb',
#   'what',
#   'logic',
#   'and',
#   'why',
#   'writing',
#   'machine',
#   'human',
#   'help',
#   'required'],
#  ['united',
#   'cancelled',
#   'flightn',
#   'left',
#   'fend',
#   'flt',
#   'came',
#   'late',
#   'flight',
#   'getting',
#   'runaround',
#   'hr',
#   'each',
#   'employee',
#   'blaming',
#   'previous'],
#  ['united',
#   'yes',
#   'still',
#   'answer',
#   'many',
#   'luggage',
#   'day',
#   'unacceptable'],
#  ['united',
#   'people',
#   'getting',
#   'pretty',
#   'tired',
#   'action',
#   'solving',
#   'problem',
#   'plus',
#   'missing',
#   'day',
#   'vacation',
#   'skiing'],
#  ['united',
#   'take',
#   'back',
#   'comment',
#   'team',
#   'working',
#   'hard',
#   'help',
#   'far',
#   'solution',
#   'hotel',
#   'food',
#   'anything',
#   'fail'],
#  ['united',
#   'arriving',
#   'two',
#   'hour',
#   'late',
#   'flight',
#   'clt',
#   'now',
#   'sitting',
#   'tarmac',
#   'move',
#   'plane',
#   'gate',
#   'unhappy',
#   'customer'],
#  ['united',
#   'airline',
#   'absolute',
#   'worst',
#   'they',
#   'idea',
#   'neveragain',
#   'unitedairlines'],
#  ['united',
#   'thanks',
#   'might',
#   'want',
#   'fix',
#   'line',
#   'our',
#   'customer',
#   'care',
#   'team',
#   'currently',
#   'responding',
#   'inquiry',
#   'within',
#   'business',
#   'day'],
#  ['united',
#   'frustrating',
#   'frequent',
#   'flyer',
#   'loyal',
#   'since',
#   'continental',
#   'upgrade',
#   'equal',
#   'paying',
#   'time',
#   'top',
#   'purchase',
#   'ticket'],
#  ['united',
#   'worse',
#   'figure',
#   'pack',
#   'plane',
#   'screw',
#   'connectns',
#   'claim',
#   'hotl',
#   'room',
#   'san',
#   'fran',
#   'stranded',
#   'pax',
#   'way'],
#  ['united',
#   'passenger',
#   'hour',
#   'delayed',
#   'flight',
#   'left',
#   'hotel',
#   'end',
#   'night',
#   'hou',
#   'airport',
#   'wtf',
#   'co',
#   'zfqmpgxvs'],
#  ['hey',
#   'united',
#   'flight',
#   'iah',
#   'po',
#   'leave',
#   'late',
#   'flight',
#   'one',
#   'back',
#   'iah',
#   'early',
#   'rather',
#   'get',
#   'po',
#   'earlier'],
#  ['united',
#   'lost',
#   'bag',
#   'process',
#   'broken',
#   'agent',
#   'promised',
#   'call',
#   'amp',
#   'hold',
#   'bag',
#   'found',
#   'now',
#   're',
#   'waking',
#   'am',
#   'delivery',
#   'fail'],
#  ['united',
#   'people',
#   'counter',
#   'helpful',
#   'see',
#   'nobody',
#   'flight',
#   'austin',
#   'still',
#   'sitting'],
#  ['united',
#   'good',
#   'know',
#   'open',
#   'closed',
#   'door',
#   'premier',
#   'passenger',
#   'safety',
#   'briefing',
#   'delayed',
#   'flight',
#   'annoyed'],
#  ['united',
#   'yea',
#   'get',
#   'phoenix',
#   'already',
#   'delay',
#   'day',
#   'people',
#   'bullshit'],
#  ['united',
#   'consolation',
#   'staff',
#   'stellar',
#   'just',
#   'hour',
#   'delay',
#   'encountered',
#   'every',
#   'one',
#   'flight'],
#  ['united',
#   'unfortunate',
#   'the',
#   'tumitravel',
#   'xmas',
#   'gift',
#   'look',
#   'like',
#   'razor',
#   'ripped',
#   'right',
#   'front',
#   'pocket',
#   'picture'],
#  ['united',
#   'lost',
#   'bag',
#   'cancelled',
#   'flightled',
#   'flight',
#   'delhi',
#   'call',
#   'center',
#   'poor',
#   'united',
#   'staff',
#   'spread',
#   'thin',
#   'stressed',
#   'you',
#   'name'],
#  ['united',
#   'yes',
#   'doe',
#   'make',
#   'mistake',
#   'le',
#   'absurd',
#   'doe',
#   'change',
#   'fact',
#   'inconveniently',
#   'missing',
#   'luggage',
#   'tonight'],
#  ['united',
#   'constantly',
#   'challenge',
#   'upgrade',
#   'amp',
#   'charge',
#   'order',
#   'prevent',
#   'dvt',
#   'pay',
#   'addtl',
#   'co',
#   'xc',
#   'jq'],
#  ['united',
#   'ord',
#   'waited',
#   'min',
#   'crew',
#   'member',
#   'left',
#   'gate',
#   'item',
#   'came',
#   'flight',
#   'attendant',
#   'sarcastically',
#   'said',
#   'good',
#   'luck',
#   'walked',
#   'away'],
#  ['united',
#   'agent',
#   'split',
#   'reservation',
#   'now',
#   'cancelled',
#   'flight',
#   'refund',
#   'credit',
#   'wks',
#   'why'],
#  ['united', 'would', 'make', 'share', 'room'],
#  ['united',
#   'tried',
#   'calling',
#   'min',
#   'phn',
#   'wait',
#   'mean',
#   'miss',
#   'option',
#   'anyway'],
#  ['united',
#   'ask',
#   'guy',
#   'flight',
#   'bwi',
#   'wait',
#   'get',
#   'delayed',
#   'flight',
#   'san',
#   'diego',
#   'pretty',
#   'please'],
#  ['united',
#   're',
#   'still',
#   'waiting',
#   'find',
#   'rep',
#   'working',
#   'hard',
#   'upset',
#   'wait',
#   'tomorrow',
#   'get',
#   'mammoth'],
#  ['united',
#   'early',
#   'flt',
#   'think',
#   'call',
#   'appropriate',
#   'yes',
#   'reviewed',
#   'nada',
#   'avail',
#   'next',
#   'day',
#   'expect',
#   'full',
#   'refund'],
#  ['united',
#   'ask',
#   'call',
#   'get',
#   'fixed',
#   'tweeting',
#   'question',
#   'stall',
#   'make',
#   'thing',
#   'worse',
#   'phone',
#   'number',
#   'please'],
#  ['united',
#   'stuck',
#   'tarmac',
#   'hour',
#   'fly',
#   'ohare',
#   'going',
#   'miss',
#   'ride',
#   'flypdx',
#   'help',
#   'please',
#   'helpimstuck',
#   'united'],
#  ['united',
#   'highly',
#   'unprofessional',
#   'overbook',
#   'flight',
#   'seat',
#   'amp',
#   'feel',
#   'rearrange',
#   'schedule',
#   'mismanagement'],
#  ['united',
#   'well',
#   'considering',
#   'every',
#   'agent',
#   'claimed',
#   'unable',
#   'help',
#   'everything',
#   'else',
#   'waste',
#   'time',
#   'hear',
#   'call',
#   'corp'],
#  ['united',
#   'ice',
#   'totally',
#   'understand',
#   'but',
#   'large',
#   'number',
#   'facing',
#   'hour',
#   'time',
#   'overnight',
#   'cancelled',
#   'flightations',
#   'seems',
#   'like'],
#  ['united',
#   'flt',
#   'cancelled',
#   'flightled',
#   'get',
#   'email',
#   'what',
#   'happened',
#   'courtesy',
#   'phn',
#   'call',
#   'had',
#   'book',
#   'diff',
#   'airline',
#   'amp',
#   'city'],
#  ['united',
#   'better',
#   'train',
#   'support',
#   'staff',
#   'appropriate',
#   'decorum',
#   'consider',
#   'revisiting',
#   'terrible',
#   'provide',
#   'death',
#   'certificate',
#   'policy'],
#  ['united',
#   'well',
#   'bar',
#   'set',
#   'low',
#   'you',
#   'guy',
#   'really',
#   'good',
#   'apology',
#   'game',
#   'what',
#   'change',
#   'when',
#   'guy',
#   'learn'],
#  ['united',
#   'thanks',
#   'effing',
#   'holiday',
#   're',
#   'missing',
#   'full',
#   'day',
#   'skiing',
#   'due',
#   'baggage',
#   'team',
#   'incompetence',
#   'flyyow'],
#  ['united',
#   'agent',
#   'help',
#   'person',
#   'front',
#   'finish',
#   'walk',
#   'away',
#   'the',
#   'guy',
#   'behind',
#   'shocked'],
#  ['united',
#   'connection',
#   'ord',
#   'exact',
#   'plane',
#   'checked',
#   'carry',
#   'apparently',
#   'taken',
#   'amp',
#   'left',
#   'chicago',
#   'pretty',
#   'ridiculous'],
#  ['united',
#   'yes',
#   'did',
#   'file',
#   'claim',
#   'soon',
#   'carousel',
#   'stopped',
#   'without',
#   'bag',
#   'got',
#   'email',
#   'found',
#   'sched',
#   'delivery'],
#  ['united',
#   'delay',
#   'den',
#   'cle',
#   'manually',
#   'enter',
#   'baggage',
#   'tag',
#   'really',
#   'worst',
#   'cust',
#   'service',
#   'day',
#   'ker',
#   'friendlyskies'],
#  ['united',
#   'why',
#   'tell',
#   'flight',
#   'delayed',
#   'tell',
#   'time',
#   'min',
#   'spare',
#   'say',
#   'delayed',
#   'unless',
#   're',
#   'sure'],
#  ['united',
#   'late',
#   'flight',
#   'denver',
#   'late',
#   'flight',
#   'newark',
#   'let',
#   'even',
#   'get',
#   'disaster',
#   'checking',
#   'bag',
#   'unacceptable'],
#  ['united',
#   'let',
#   'think',
#   've',
#   'ever',
#   'flown',
#   'problem',
#   'worst',
#   'airline',
#   'period'],
#  ['united',
#   'yes',
#   'filed',
#   'claim',
#   'amp',
#   'hope',
#   'receive',
#   'luggage',
#   'am',
#   'ridiculous',
#   'purchase',
#   'item',
#   'sleep',
#   'amp',
#   'reimbursement'],
#  ['united',
#   'ua',
#   'ord',
#   'lhr',
#   'bag',
#   'loaded',
#   'min',
#   'late',
#   'flight',
#   'frigid',
#   'air',
#   'cabin',
#   'plane',
#   'feel',
#   'like',
#   'falling',
#   'apart',
#   'upgrade',
#   'long',
#   'haul',
#   'fleet'],
#  ['united',
#   'flight',
#   'attendant',
#   'never',
#   'served',
#   'beverage',
#   'tea',
#   'checked',
#   'what',
#   'give',
#   'ua',
#   'notcool'],
#  ['united',
#   'americanair',
#   'spent',
#   'hundred',
#   'rectify',
#   'situation',
#   'guy',
#   'quiet'],
#  ['united',
#   'ua',
#   'sitting',
#   'ewr',
#   'nearly',
#   'hour',
#   'sked',
#   'pilot',
#   'say',
#   'computer',
#   'clue',
#   'leave',
#   'can',
#   'help'],
#  ['united',
#   'americanair',
#   'end',
#   'come',
#   'traveled',
#   'literally',
#   'extra',
#   'day',
#   'half'],
#  ['united',
#   'received',
#   'luggage',
#   'also',
#   'looked',
#   'left',
#   'snow',
#   'arrived',
#   'asking',
#   'people',
#   'refunded'],
#  ['united',
#   'updated',
#   'aircraft',
#   'wifi',
#   'device',
#   'entertainment',
#   'outlet',
#   'get',
#   'how',
#   'charge',
#   'device'],
#  ['united',
#   'one',
#   'scan',
#   'inside',
#   'plane',
#   'asked',
#   'people',
#   'line',
#   'around',
#   'plane',
#   'going'],
#  ['united',
#   'gate',
#   'change',
#   'two',
#   'delay',
#   'even',
#   'crew',
#   'think',
#   'airline',
#   'suck'],
#  ['united', 'frustrated', 'wasted', 'day', 'due', 'equipment', 'failure'],
#  ['united',
#   'computer',
#   'stopped',
#   'giving',
#   'update',
#   'took',
#   'flight',
#   'info',
#   'app',
#   'that',
#   'ridiculous',
#   'keep',
#   'people',
#   'updated'],
#  ['united',
#   'soooo',
#   'day',
#   've',
#   'offered',
#   'response',
#   'assume',
#   'poor',
#   'treatment',
#   'gate',
#   'agent',
#   'norm'],
#  ['united',
#   'call',
#   'resulted',
#   'hrs',
#   'hold',
#   'time',
#   'amp',
#   'day',
#   'wait',
#   'check',
#   'suspect',
#   'code',
#   'share',
#   'fare',
#   'nothing',
#   'investigated',
#   'my',
#   'time',
#   'wasted'],
#  ['united',
#   'taken',
#   'week',
#   'cust',
#   'care',
#   'respond',
#   'case',
#   'requesting',
#   'refund',
#   'working',
#   'where',
#   'get',
#   'update'],
#  ['united',
#   'that',
#   'correct',
#   've',
#   'spent',
#   'hour',
#   'trying',
#   'book',
#   'online',
#   'receive',
#   'error',
#   'clicking',
#   'final',
#   'purchase',
#   'button'],
#  ['united',
#   'today',
#   'finest',
#   'all',
#   'could',
#   'prevented',
#   'one',
#   'gate',
#   'agent',
#   'advising',
#   'passenger'],
#  ['united', 'real', 'deal', 'delay', 'flight', 'denver', 'vega'],
#  ['united',
#   'ua',
#   'madrid',
#   'arrived',
#   'agent',
#   'mass',
#   'confusion',
#   'sent',
#   'fro',
#   'employee',
#   'maryjo',
#   'rude',
#   'unhelpful'],
#  ['united',
#   'system',
#   'failure',
#   'bad',
#   'trend',
#   'software',
#   'project',
#   'like',
#   'flying',
#   'airplane',
#   'thing',
#   'emergency',
#   'takeoff'],
#  ['united',
#   'lot',
#   'report',
#   'system',
#   'failure',
#   'delaying',
#   'flight',
#   'last',
#   'week',
#   'currently',
#   'sitting',
#   'tarmac',
#   'ogg',
#   'hour'],
#  ['united',
#   'co',
#   'hj',
#   'kq',
#   'chn',
#   'however',
#   'completely',
#   'control',
#   'the',
#   'price',
#   'still',
#   'displayed',
#   'co',
#   'hj',
#   'kq',
#   'chn'],
#  ['united',
#   'would',
#   'contact',
#   'discus',
#   'poor',
#   'experience',
#   'customer',
#   'service',
#   'would',
#   'give',
#   'shot'],
#  ['united',
#   'pacific',
#   'rim',
#   'date',
#   'night',
#   'cut',
#   'not',
#   'constantly',
#   'randomly',
#   'one',
#   'spot',
#   'repeatably'],
#  ['united', 'been', 'trying', 'since', 'file', 'report'],
#  ['united',
#   'send',
#   'email',
#   'bad',
#   'experience',
#   'send',
#   'back',
#   'generic',
#   'response',
#   'yet',
#   'another',
#   'reason',
#   'll',
#   'never',
#   'fly'],
#  ['united',
#   'horrible',
#   'they',
#   'lost',
#   'carseat',
#   'expect',
#   'use',
#   'loner',
#   'carseat',
#   'safety',
#   'regulation',
#   'say',
#   'illegal',
#   'use',
#   'used',
#   'car',
#   'seat'],
#  ['united',
#   'care',
#   'thehipmunk',
#   'link',
#   'showed',
#   'wrong',
#   'price',
#   'site',
#   'it',
#   'site',
#   'amp',
#   'responsibility',
#   'ensure',
#   'correctness'],
#  ['united',
#   'mllovelace',
#   'the',
#   'baggage',
#   'fee',
#   'waived',
#   'premier',
#   'member',
#   'please',
#   'see',
#   'co',
#   'duw',
#   'mde',
#   'jp',
#   'point',
#   'membership'],
#  ['united',
#   'wonderful',
#   'bag',
#   'claim',
#   'people',
#   'finally',
#   'bag',
#   'but',
#   'catch',
#   'earlier',
#   'flight',
#   'original',
#   'flight',
#   'landed',
#   'wastedtime'],
#  ['united',
#   'day',
#   'late',
#   'flightr',
#   'bag',
#   'left',
#   'iad',
#   'united',
#   'helping',
#   'everyone',
#   'tell',
#   'different',
#   'story'],
#  ['united',
#   'lose',
#   'gate',
#   'checked',
#   'bag',
#   'den',
#   'ord',
#   'direct',
#   'flight',
#   'ugh'],
#  ['united',
#   'caught',
#   'earlier',
#   'flight',
#   'ord',
#   'gate',
#   'checked',
#   'bag',
#   've',
#   'lost',
#   'hare',
#   'original',
#   'flight',
#   'land',
#   'minutes',
#   'frustrating'],
#  ['united', 'can', 'please', 'follow', 'missing', 'bag'],
#  ['united',
#   'left',
#   'item',
#   'plane',
#   'calling',
#   'non',
#   'stop',
#   'one',
#   'answering',
#   'please',
#   'help'],
#  ['united',
#   'good',
#   'number',
#   'call',
#   'speak',
#   'someone',
#   'fix',
#   'people',
#   'luggage',
#   'saturday'],
#  ['united', 'damn', 'bag'],
#  ['united',
#   'well',
#   'someone',
#   'tell',
#   'employee',
#   'denver',
#   'baggage',
#   'claim',
#   'still',
#   'bag'],
#  ['united',
#   'diverted',
#   'missed',
#   'connecting',
#   'flight',
#   'wa',
#   'told',
#   'bag',
#   'way',
#   'msy',
#   'people',
#   'cared'],
#  ['united',
#   'male',
#   'agnt',
#   'la',
#   'threatens',
#   'canadian',
#   'cust',
#   'cust',
#   'take',
#   'pic',
#   'gate',
#   'agent',
#   'announce',
#   'help',
#   'rebook',
#   'friendlyskies'],
#  ['united',
#   'apollochplayers',
#   'want',
#   'home',
#   'tonight',
#   'cancelled',
#   'flight',
#   'last',
#   'leg',
#   'reserv',
#   'permission',
#   'ph',
#   'rps'],
#  ['united',
#   'stressed',
#   'rude',
#   'agent',
#   'overwhelmed',
#   'delyd',
#   'flight',
#   'la',
#   'den',
#   'yelling',
#   'several',
#   'people',
#   'not',
#   'pretty',
#   'this',
#   'friendlyskies'],
#  ['united',
#   'fail',
#   'you',
#   'cancelled',
#   'flightled',
#   'flight',
#   'frm',
#   'gjt',
#   'used',
#   'reserv',
#   'home',
#   'iah',
#   'sea',
#   'reflight',
#   'booking',
#   'problem',
#   'our',
#   'permission',
#   'ph',
#   'rps'],
#  ['united',
#   'made',
#   'fly',
#   'list',
#   'other',
#   'airline',
#   'wait',
#   'connector',
#   'late',
#   'flight',
#   'stuck',
#   'iah'],
#  ['united',
#   'co',
#   'hpsqvrjk',
#   'flight',
#   'gone',
#   'got',
#   'plane',
#   'businesstravel'],
#  ['united',
#   'proper',
#   'response',
#   'sorry',
#   'wait',
#   'flight',
#   'look',
#   'issue',
#   'that',
#   'delta',
#   'would',
#   'handle'],
#  ['united',
#   'customer',
#   'service',
#   'terrible',
#   'stood',
#   'inline',
#   'hour',
#   'flight',
#   'hour',
#   'late',
#   'flightr',
#   'still',
#   'bag'],
#  ['united',
#   'boarding',
#   'time',
#   'show',
#   'min',
#   'gate',
#   'agent',
#   'started',
#   'showed',
#   'check',
#   'bag',
#   'co',
#   'zcbjyo',
#   'lsn'],
#  ['united',
#   'agent',
#   'la',
#   'letting',
#   'customer',
#   'know',
#   'help',
#   'rebook',
#   'delayed',
#   'flight',
#   'den',
#   'unfriendlyskies',
#   'co',
#   'quzvmk',
#   'rtr'],
#  ['united',
#   'empathizes',
#   'disappointment',
#   'stclass',
#   'flight',
#   'nonworking',
#   'entertainmnt',
#   'worth',
#   'unfriendlyskies',
#   'co',
#   'loeco',
#   'gmvd'],
#  ['united', 'work'],
#  ['united',
#   'searched',
#   'mileage',
#   'ticket',
#   'bom',
#   'could',
#   'find',
#   'single',
#   'one',
#   'saver',
#   'award',
#   'see',
#   'play',
#   'earn',
#   'mile',
#   'use'],
#  ['united',
#   'that',
#   'issue',
#   'the',
#   'fact',
#   'one',
#   'even',
#   'called',
#   'despite',
#   'promise',
#   'confirm',
#   'bag',
#   'location'],
#  ['united',
#   'still',
#   'waiting',
#   'hear',
#   'back',
#   'wallet',
#   'stolen',
#   'one',
#   'plane',
#   'would',
#   'appreciate',
#   'resolution'],
#  ['united',
#   'flysaa',
#   'lost',
#   'baggage',
#   'heard',
#   'different',
#   'thing',
#   'different',
#   'employee',
#   'united',
#   'flysaa',
#   'said',
#   'nothing'],
#  ['united',
#   'think',
#   'mile',
#   'repair',
#   'damage',
#   'done',
#   'interesting',
#   'travel',
#   'united',
#   'exp',
#   'worst',
#   'flight',
#   'ever'],
#  ['united',
#   'signed',
#   'notification',
#   'this',
#   'first',
#   'trip',
#   'updated',
#   'not',
#   'sure',
#   'happened'],
#  ['united',
#   'line',
#   'response',
#   'and',
#   'waiting',
#   'tomorrow',
#   'morning',
#   'flight',
#   'overbooked'],
#  ['united',
#   'took',
#   'exact',
#   'aircraft',
#   'lax',
#   'day',
#   'ago',
#   'fit',
# ...
#   'boarding',
#   'min',
#   'late',
#   'flight',
#   'trying',
#   'figure',
#   'issue'],
#  ['united',
#   'waiting',
#   'half',
#   'hour',
#   'checked',
#   'bag',
#   'ewr',
#   'amp',
#   'priority',
#   'disappointing',
#   'usually',
#   'guy',
#   'good'],
#  ['united',
#   'are',
#   'earnings',
#   'low',
#   'checkin',
#   'people',
#   'also',
#   'tarmac',
#   'loading',
#   'bag',
#   'jan'],
#  ['united',
#   'thank',
#   'dishonoring',
#   'upgrade',
#   'putting',
#   'seat',
#   'want',
#   'even',
#   'notifying',
#   'great',
#   'service'],
#  ['united', 'guy', 'gay'],
#  ['united',
#   'email',
#   'call',
#   'past',
#   'month',
#   'flight',
#   'change',
#   'helpful',
#   'wish',
#   'would',
#   'sent',
#   'cancelled',
#   'flightlation',
#   'yesterday'],
#  ['united',
#   'changed',
#   'depart',
#   'pm',
#   'amp',
#   'pm',
#   'amp',
#   'capt',
#   'got',
#   'plane',
#   'find',
#   'smoothie',
#   'pm',
#   'as'],
#  ['united',
#   'thanks',
#   'nothing',
#   'atlanta',
#   'lounge',
#   'your',
#   'say',
#   'sure',
#   'nothing',
#   'terminal',
#   'co',
#   'tfjfmsha'],
#  ['united',
#   'would',
#   'make',
#   'day',
#   'could',
#   'take',
#   'flight',
#   'airline',
#   'without',
#   'hiccup',
#   'end',
#   'train',
#   'employee',
#   'communicate'],
#  ['united',
#   'baby',
#   'shit',
#   'pant',
#   'half',
#   'way',
#   'flight',
#   'smelled',
#   'like',
#   'shit',
#   'going'],
#  ['united',
#   'you',
#   'cause',
#   'miss',
#   'flight',
#   'telling',
#   'already',
#   'left',
#   'empathy',
#   'gate',
#   'staff',
#   'crew',
#   'apology',
#   'really'],
#  ['united',
#   'rescheduled',
#   'return',
#   'flight',
#   'japan',
#   'trying',
#   'call',
#   'unitedairlines',
#   'customerservice',
#   'min',
#   'wait',
#   'fun'],
#  ['united', 'far', 'worst', 'airline', 'ever'],
#  ['united',
#   'appalled',
#   'lack',
#   'communication',
#   'awful',
#   'journey',
#   'ewr',
#   'bos',
#   'delay',
#   'need',
#   'explained',
#   'better'],
#  ['united',
#   'dming',
#   'info',
#   'assisting',
#   'flight',
#   'home',
#   'left',
#   'first',
#   'flight',
#   'even',
#   'landed'],
#  ['united',
#   'boston',
#   'self',
#   'service',
#   'swipe',
#   'boarding',
#   'pas',
#   'gate',
#   'most',
#   'difficult',
#   'tag',
#   'bag',
#   'not',
#   'easy'],
#  ['united', 'people', 'would', 'catch', 'flight', 'attendant', 'help'],
#  ['united',
#   'consistency',
#   'denver',
#   'agent',
#   'say',
#   'standby',
#   'checked',
#   'baggage',
#   'citing',
#   'faa',
#   'your',
#   'website',
#   'policy',
#   'say',
#   'otherwise',
#   'time',
#   'switch'],
#  ['only',
#   'biz',
#   'day',
#   'calendar',
#   'respond',
#   'inquiry',
#   'united',
#   'hope',
#   'standard',
#   'universally',
#   'adopted'],
#  ['united',
#   'thanks',
#   'occur',
#   'you',
#   'guy',
#   'hour',
#   'extra',
#   'get',
#   'bag',
#   'due',
#   'delay',
#   'hour',
#   'fail'],
#  ['united',
#   'many',
#   'delay',
#   'today',
#   'what',
#   'hoping',
#   'pm',
#   'flight',
#   'board',
#   'soon',
#   'united',
#   'premier'],
#  ['united',
#   'website',
#   'fucked',
#   'now',
#   'instead',
#   'flight',
#   'yesterday',
#   'today',
#   'thanks'],
#  ['united',
#   'called',
#   'back',
#   've',
#   'hold',
#   'what',
#   'issue',
#   'confirmation',
#   'number',
#   'email',
#   'show',
#   'much',
#   've',
#   'paid'],
#  ['united',
#   'sure',
#   'help',
#   'your',
#   'flight',
#   'experience',
#   'terrible',
#   'plane',
#   'dirty',
#   'staff',
#   'rude',
#   'start',
#   'perhaps'],
#  ['united',
#   'check',
#   'still',
#   'saying',
#   'paid',
#   've',
#   'called',
#   'back',
#   'twice',
#   'hold',
#   'minute',
#   'answered',
#   'hung'],
#  ['united',
#   'hold',
#   'minute',
#   'finally',
#   'got',
#   'someone',
#   'retook',
#   'form',
#   'payment',
#   'confirmed',
#   'reservation',
#   'set',
#   'tried'],
#  ['united',
#   'bought',
#   'ticket',
#   'yesterday',
#   'received',
#   'confirmation',
#   'tried',
#   'check',
#   'said',
#   'paid',
#   'called'],
#  ['united',
#   'delayed',
#   'salt',
#   'floor',
#   'previous',
#   'passenger',
#   'the',
#   'want',
#   'fly',
#   'care',
#   'shoe',
#   'ua'],
#  ['united',
#   'czamkoff',
#   'profit',
#   'really',
#   'give',
#   'damn',
#   'paying',
#   'customer',
#   'greed'],
#  ['united', 'unfortunately', 'get', 'name', 'nice'],
#  ['united', 'seat', 'international', 'connection', 'seriously'],
#  ['united', 'bag', 'lost', 'get', 'ahold', 'anyone', 'help'],
#  ['united',
#   'then',
#   'delete',
#   'return',
#   'ticket',
#   'europe',
#   'blame',
#   'show',
#   'this',
#   'airline',
#   'joke',
#   'time',
#   'happened',
#   'now',
#   'time'],
#  ['united',
#   'when',
#   'united',
#   'flight',
#   'arrives',
#   'late',
#   'flight',
#   'told',
#   'book',
#   'connecting',
#   'united',
#   'flight',
#   'characterize',
#   'show'],
#  ['united', 'never', 'flying', 'united', 'worst', 'experience', 'ever'],
#  ['united',
#   'tiffanyandco',
#   'ntrustopen',
#   'fund',
#   'fix',
#   'broken',
#   'plane',
#   'upon',
#   'sat',
#   'hr',
#   'iah',
#   'runway',
#   'went'],
#  ['united', 'direct', 'message', 'follow', 'want', 'luggage', 'please', 'hep'],
#  ['united',
#   'flight',
#   'stranded',
#   'tarmac',
#   'chicago',
#   'gate',
#   'available',
#   'plane',
#   'getting',
#   'hot',
#   'uncomfortable'],
#  ['united',
#   'rebooked',
#   'disappointed',
#   'wait',
#   'whole',
#   'day',
#   'start',
#   'vacation',
#   'fare',
#   'united',
#   'top',
#   'notch',
#   'service'],
#  ['united',
#   'assume',
#   'would',
#   'people',
#   'let',
#   'united',
#   'what',
#   'worse',
#   'plane',
#   'crew',
#   'fly'],
#  ['united', 'pushing', 'hour', 'hold', 'priceless', 'co', 'ths', 'ldy'],
#  ['united',
#   'read',
#   'thread',
#   'booked',
#   'st',
#   'class',
#   'seated',
#   'even',
#   'though',
#   'united',
#   'twtr',
#   'account',
#   'confirmed',
#   'eco',
#   'premium'],
#  ['united',
#   'bag',
#   'ua',
#   'update',
#   'explain',
#   'occurred',
#   'arrived',
#   'hour',
#   'flight'],
#  ['united',
#   'yes',
#   'need',
#   'free',
#   'hotel',
#   'stay',
#   'honalulu',
#   'due',
#   'hour',
#   'delayua',
#   'since',
#   'miss',
#   'second',
#   'flight',
#   'kauai'],
#  ['united',
#   'screwing',
#   'flight',
#   'cae',
#   'why',
#   'bother',
#   'flight',
#   'never',
#   'leave',
#   'time',
#   'get',
#   'cancelled',
#   'flighted'],
#  ['united', 'need', 'agent', 'check'],
#  ['united',
#   'work',
#   'incredibly',
#   'unfriendly',
#   'ground',
#   'staff',
#   'false',
#   'promise',
#   'twitter',
#   'theairhelper'],
#  ['united',
#   'the',
#   'skilled',
#   'staff',
#   'inadequate',
#   'system',
#   'deleted',
#   'return',
#   'houston',
#   'norway',
#   'shoulder',
#   'shrugging'],
#  ['united', 'severely', 'staffed', 'iah'],
#  ['united', 'delay', 'vacation', 'buzzkill'],
#  ['united',
#   'really',
#   'enjoying',
#   'sunday',
#   'hold',
#   'hour',
#   'perhaps',
#   'better',
#   'client',
#   'experience',
#   'needed',
#   'co',
#   'vnckgzxl'],
#  ['united',
#   'broken',
#   'light',
#   'min',
#   'get',
#   'bridge',
#   'gate',
#   'airplane',
#   'parked',
#   'wrong',
#   'bathroom',
#   'emptied',
#   'last',
#   'night',
#   'airline',
#   'last',
#   'hr'],
#  ['united',
#   'would',
#   'appreciate',
#   'response',
#   'regarding',
#   'pressurization',
#   'failure',
#   'flight',
#   'you',
#   'seem',
#   'responding',
#   'le',
#   'serious',
#   'issue'],
#  ['united',
#   'guy',
#   'let',
#   'four',
#   'hour',
#   'delay',
#   'honolulu',
#   'houston',
#   'thanks',
#   'train',
#   'wreck',
#   'issue',
#   'coming'],
#  ['united', 'another', 'flight', 'gate', 'held', 'min', 'cnx', 'pax'],
#  ['united',
#   'geiger',
#   'look',
#   'like',
#   'form',
#   'photo',
#   'something',
#   'burst',
#   'luggage',
#   'correct',
#   'jh',
#   'always',
#   'blame',
#   'customer'],
#  ['united', 'boarding', 'time', 'ua', 'crewe'],
#  ['united',
#   'way',
#   'one',
#   'person',
#   'working',
#   'entire',
#   'security',
#   'checkpoint',
#   'ewr'],
#  ['united',
#   'author',
#   'fiction',
#   'heard',
#   'radio',
#   'even',
#   'jetway',
#   'secured',
#   'yet',
#   'ua',
#   'cmh',
#   'co',
#   'abtwf'],
#  ['united',
#   'found',
#   'anything',
#   'showing',
#   'you',
#   'realise',
#   'morning',
#   'flight',
#   'cancelled',
#   'flightled',
#   'pricey',
#   'evening'],
#  ['united',
#   'wa',
#   'still',
#   'lost',
#   'your',
#   'tracking',
#   'system',
#   'stink',
#   'delivery',
#   'system'],
#  ['united',
#   'feeling',
#   'like',
#   'true',
#   'united',
#   'customer',
#   'stuck',
#   'on',
#   'tarmac',
#   'hr',
#   'unitedfail'],
#  ['united',
#   'leadership',
#   'count',
#   'landed',
#   'last',
#   'night',
#   'deplaned',
#   'minute',
#   'waiting',
#   'jetway',
#   'inexcusable'],
#  ['united',
#   'sent',
#   'requested',
#   'heard',
#   'anything',
#   'can',
#   'address',
#   'issue',
#   'brought',
#   'explain',
#   'happened'],
#  ['united',
#   'employee',
#   'faceless',
#   'throw',
#   'bus',
#   'start',
#   'management',
#   'almost',
#   'million',
#   'miler',
#   'company'],
#  ['united',
#   'say',
#   'flight',
#   'pulled',
#   'departs',
#   'min',
#   'boarding',
#   'even',
#   'started',
#   'co',
#   'ikbp',
#   'gxwi'],
#  ['united',
#   'understand',
#   'pay',
#   'change',
#   'problem',
#   'plane',
#   'weather',
#   'would',
#   'understand'],
#  ['united',
#   'hour',
#   'late',
#   'flightr',
#   'still',
#   'answer',
#   'stuck',
#   'houston',
#   'keep',
#   'getting',
#   'put',
#   'phantom',
#   'flight',
#   'never',
#   'apeared'],
#  ['united',
#   'guy',
#   'horrible',
#   'first',
#   'get',
#   'stuck',
#   'snow',
#   'ewr',
#   'sitting',
#   'cmh',
#   'saying',
#   'could',
#   'min',
#   'gate'],
#  ['united',
#   'hotel',
#   'sent',
#   'wouldnt',
#   'take',
#   'voucher',
#   'our',
#   'flight',
#   'delayed',
#   'cancelled',
#   'flightled',
#   'delayed',
#   'hour',
#   'counting'],
#  ['united', 'hr', 'ago', 'request', 'response', 'found', 'like', 'bag'],
#  ['united',
#   'two',
#   'hour',
#   'delay',
#   'plane',
#   'visible',
#   'airport',
#   'far',
#   'terrible',
#   'customer',
#   'service',
#   'neveragain'],
#  ['united',
#   'hour',
#   'maintenance',
#   'delay',
#   'enuf',
#   'charge',
#   'bag',
#   'global',
#   'service',
#   'platinum',
#   'mbr',
#   'get',
#   'shit',
#   'together'],
#  ['united',
#   'last',
#   'week',
#   'also',
#   'maintenance',
#   'issue',
#   'flat',
#   'tire',
#   'another',
#   'flight',
#   'last',
#   'week',
#   'cancelled',
#   'flighted',
#   'your',
#   'track',
#   'record',
#   'worst'],
#  ['united',
#   'spend',
#   'money',
#   'take',
#   'ticket',
#   'update',
#   'plane',
#   'each',
#   'flight',
#   'maintenance',
#   'issue'],
#  ['united',
#   'chance',
#   'could',
#   'help',
#   'rebook',
#   'flight',
#   'cancelled',
#   'flightled'],
#  ['united',
#   'really',
#   'need',
#   'better',
#   'system',
#   'handling',
#   'cancelled',
#   'flightled',
#   'flight',
#   'co',
#   'ubcoasyws'],
#  ['united',
#   'also',
#   'inappropriate',
#   'lie',
#   'passenger',
#   'induce',
#   'accepting',
#   'voucher',
#   'telling',
#   'availability',
#   'late',
#   'flightr'],
#  ['united',
#   'give',
#   'direct',
#   'number',
#   'call',
#   'regarding',
#   'lost',
#   'baggage',
#   'immediately'],
#  ['united',
#   'involuntarily',
#   'bumped',
#   'passenger',
#   'guarantee',
#   'another',
#   'flight',
#   'three',
#   'day'],
#  ['united',
#   'please',
#   'follow',
#   'faa',
#   'guideline',
#   'regarding',
#   'bumping',
#   'not',
#   'acceptable',
#   'give',
#   'voucher',
#   'fare',
#   've'],
#  ['united',
#   'already',
#   'rebook',
#   'miss',
#   'first',
#   'appointment',
#   'london',
#   'tomorrow',
#   'morning',
#   'thanks',
#   'ruining',
#   'trip',
#   'again'],
#  ['united', 'our', 'newest', 'delay', 'right', 'co', 'ftlzwtvo'],
#  ['united',
#   'show',
#   'available',
#   'seat',
#   'need',
#   'honor',
#   'shouldnt',
#   'spend',
#   'hr',
#   'phone',
#   'hear',
#   'really',
#   'seat'],
#  ['united',
#   'min',
#   'hold',
#   'trying',
#   'book',
#   'award',
#   'flight',
#   'site',
#   'error',
#   'agent',
#   'ask',
#   'pin',
#   'see',
#   'platinum',
#   'availability',
#   'badbadbad'],
#  ['united', 'joke', 'lot', 'angry', 'people', 'iah'],
#  ['united',
#   'completely',
#   'unacceptable',
#   'seat',
#   'st',
#   'class',
#   'passenger',
#   'middle',
#   'seat',
#   'even',
#   'premium',
#   'economy'],
#  ['united',
#   'found',
#   'flight',
#   'hr',
#   'how',
#   'offered',
#   'flight',
#   'voucher',
#   'hr',
#   'lose',
#   'seat',
#   'neglect',
#   'get',
#   'nothing'],
#  ['united',
#   'right',
#   'think',
#   'take',
#   'stop',
#   'get',
#   'iced',
#   'why',
#   'done',
#   'plane',
#   'sitting',
#   'night'],
#  ['united',
#   'two',
#   'service',
#   'agent',
#   'hung',
#   'third',
#   'able',
#   'get',
#   'flight',
#   'air',
#   'today',
#   'three',
#   'call',
#   'hour',
#   'get',
#   'flight'],
#  ['united',
#   'delayed',
#   'day',
#   'mco',
#   'iad',
#   'finger',
#   'crossed',
#   'make',
#   'connection',
#   'home',
#   'albany',
#   'united'],
#  ['united',
#   'first',
#   'class',
#   'joke',
#   'compared',
#   'others',
#   'flown',
#   'ask',
#   'extra',
#   'peanut',
#   'that',
#   'not',
#   'allowed',
#   'aircanada'],
#  ['united',
#   'given',
#   'connection',
#   'overnight',
#   'layover',
#   'voucher',
#   'last',
#   'connection',
#   'even',
#   'confirmed'],
#  ['united',
#   'would',
#   'like',
#   'baggage',
#   'damage',
#   'number',
#   'well',
#   'another',
#   'great',
#   'thing',
#   'trained',
#   'staff',
#   'whats',
#   'number',
#   'please',
#   'claim',
#   'time'],
#  ['united',
#   'put',
#   'together',
#   'serious',
#   'email',
#   'issue',
#   'arose',
#   'vacation',
#   'due',
#   'staff',
#   'post'],
#  ['united',
#   'long',
#   'wait',
#   'icing',
#   'cake',
#   'why',
#   'fix',
#   'reservation',
#   'system',
#   'confirm',
#   'get',
#   'changed',
#   'mid',
#   'travel'],
#  ['united',
#   'guy',
#   'suck',
#   'another',
#   'cancelled',
#   'flighted',
#   'flight',
#   'every',
#   'flight',
#   'issue'],
#  ['united', 'lie', 'co', 'beqotlnugc'],
#  ['united',
#   'would',
#   'let',
#   'real',
#   'nice',
#   'just',
#   'love',
#   'awesome',
#   'service',
#   'and',
#   'people',
#   'working',
#   'customer',
#   'service',
#   'line'],
#  ['united',
#   'hour',
#   'plus',
#   'delay',
#   'washingtondc',
#   'finally',
#   'flight',
#   'edinburgh',
#   'tired'],
#  ['united', 'believe', 'co', 'gqebfk'],
#  ['united',
#   'flight',
#   'delayed',
#   'hour',
#   'lost',
#   'wallet',
#   'money',
#   'eat',
#   'sleep',
#   'yet',
#   'representative',
#   'help',
#   'unitedsucks'],
#  ['united',
#   'lost',
#   'loyal',
#   'customer',
#   'mileage',
#   'plus',
#   'card',
#   'holder',
#   'could',
#   'driven',
#   'florida',
#   'quicker',
#   'way',
#   'worst',
#   'trip',
#   'ever'],
#  ['united', 'ice', 'plane', 'sits', 'one', 'hour', 'could', 'delay'],
#  ['united', 'fuck', 'caring'],
#  ['united',
#   'minute',
#   'plus',
#   'get',
#   'two',
#   'first',
#   'one',
#   'transferred',
#   'spanish',
#   'hotline',
#   'unacceptable'],
#  ['united',
#   'delta',
#   'lost',
#   'luggage',
#   'atl',
#   'hdn',
#   'luggage',
#   'denver',
#   'said',
#   'united',
#   'deliver',
#   'luggage',
#   'hdn',
#   'airport',
#   'claim',
#   'hdndl'],
#  ['united',
#   'united',
#   'loses',
#   'baggage',
#   'get',
#   'airport',
#   'country',
#   'disappears'],
#  ['united',
#   'thank',
#   'wasting',
#   'time',
#   'amp',
#   'money',
#   'not',
#   'arrive',
#   'hour',
#   'late',
#   'flight',
#   'destination'],
#  ['united',
#   'not',
#   'fly',
#   'united',
#   'with',
#   'checked',
#   'baggage',
#   'never',
#   'find'],
#  ['united',
#   'english',
#   'spanish',
#   'rep',
#   'call',
#   'locate',
#   'bag',
#   'resolve',
#   'issue'],
#  ['united',
#   'would',
#   'overnight',
#   'bag',
#   'wed',
#   'unknown',
#   'location',
#   'courier',
#   'company',
#   'apparently',
#   'contact'],
#  ['united',
#   'hey',
#   'thanks',
#   'helping',
#   'miss',
#   'buddy',
#   'th',
#   'bday',
#   'guy',
#   'really',
#   'trashy',
#   'company',
#   'unitedsucks'],
#  ['united',
#   'never',
#   'frustrated',
#   'conversation',
#   'united',
#   'speak',
#   'spanish',
#   'courier',
#   'company',
#   'bag'],
#  ['united',
#   'never',
#   'mislead',
#   'company',
#   'many',
#   'time',
#   'week',
#   'united',
#   'airline'],
#  ['united', 'would', 'never', 'fly', 'united', 'airline'],
#  ['united', 'still', 'airport', 'waiting', 'flight'],
#  ['united',
#   'airline',
#   'telling',
#   'luggage',
#   'one',
#   'hour',
#   'away',
#   'destination',
#   'day'],
#  ['united', 'one', 'operate', 'ramp', 'let', 'plane', 'iah', 'wow', 'wow'],
#  ['united',
#   'cancelled',
#   'flight',
#   'flight',
#   'sends',
#   'email',
#   'saying',
#   'think',
#   'next',
#   'flight',
#   'customer',
#   'outrage',
#   'co',
#   'kkwiwi'],
#  ['united',
#   'super',
#   'computer',
#   'ots',
#   'pant',
#   'lot',
#   'cranky',
#   'people',
#   'line',
#   'cmh',
#   'reflight',
#   'booking',
#   'problem',
#   'delaying',
#   'check',
#   'in',
#   'time',
#   'direct',
#   'flyer'],
#  ['united',
#   'check',
#   'system',
#   'trouble',
#   'checking',
#   'flight',
#   'departs',
#   'le',
#   'hr'],
#  ['united',
#   'fuck',
#   'closed',
#   'premier',
#   'access',
#   'line',
#   'ord',
#   'probably',
#   'gon',
#   'miss',
#   'flight',
#   'start',
#   'treating',
#   'customer',
#   'better'],
#  ['united',
#   'good',
#   'luck',
#   'enertainment',
#   'hour',
#   'flight',
#   'strategy',
#   'innovation',
#   'work',
#   'hello',
#   'jetblue',
#   'co',
#   'hi',
#   'boavxy'],
#  ['united',
#   'human',
#   'contact',
#   'mths',
#   'americanair',
#   'cust',
#   'relation',
#   'refund',
#   'dept',
#   'ever',
#   'problem',
#   'human',
#   'talk'],
#  ...]

# %%
# Préparation des sentences (tokenization)

print("Fit Tokenizer ...")

tokenizer = Tokenizer()
tkk = tokenizer.fit_on_texts(sentences)
x_sentences = pad_sequences(tokenizer.texts_to_sequences(sentences),
                                                     maxlen=maxlen,
                                                     padding='post') 
                                                   
num_words = len(tokenizer.word_index) + 1
print("Number of unique words: %i" % num_words)
# Out:
# Fit Tokenizer ...
# Number of unique words: 4810

# %%
tkk

# %%
tokenizer

# %%
x_sentences
# Out:
# array([[   9,   51, 1450, ...,    0,    0,    0],
#        [   9,   51,  182, ...,    0,    0,    0],
#        [   9,  246,   28, ...,    0,    0,    0],
#        ...,
#        [  10,  701,    8, ...,    0,    0,    0],
#        [  10,  119,  711, ...,    0,    0,    0],
#        [  10, 1132,   14, ...,    0,    0,    0]])

# %% [markdown]
# ## Création de la matrice d'embedding

# %%
# Création de la matrice d'embedding

print("Create Embedding matrix ...")
w2v_size = 300
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
embedding_matrix = np.zeros((vocab_size, w2v_size))
i=0
j=0
    
for word, idx in word_index.items():
    i +=1
    if word in w2v_words:
        j +=1
        embedding_vector = model_vectors[word]
        if embedding_vector is not None:
            embedding_matrix[idx] = model_vectors[word]
            
word_rate = np.round(j/i,4)
print("Word embedding rate : ", word_rate)
print("Embedding matrix: %s" % str(embedding_matrix.shape))
# Out:
# Create Embedding matrix ...
# Word embedding rate :  1.0
# Embedding matrix: (4810, 300)

# %%
vocab_size
# Out:
# 4810

# %%
type(word_index)
# Out:
# dict

# %%
len(word_index)
# Out:
# 4809

# %% [markdown]
# ## Création du modèle d'embedding

# %%
# Création du modèle

input=Input(shape=(len(x_sentences),maxlen),dtype='float64')
word_input=Input(shape=(maxlen,),dtype='float64')  
word_embedding=Embedding(input_dim=vocab_size,
                         output_dim=w2v_size,
                         weights = [embedding_matrix],
                         input_length=maxlen)(word_input)
word_vec=GlobalAveragePooling1D()(word_embedding)  
embed_model = Model([word_input],word_vec)

embed_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 24)]              0
#
#  embedding (Embedding)       (None, 24, 300)           1443000
#
#  global_average_pooling1d (G  (None, 300)              0
#  lobalAveragePooling1D)
#
# =================================================================
# Total params: 1,443,000
# Trainable params: 1,443,000
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Exécution du modèle

# %%
embeddings = embed_model.predict(x_sentences)
embeddings.shape
# Out:
# 94/94 [==============================] - 0s 1ms/step
# (3000, 300)

# %%
ARI, X_tsne, labels = ARI_fct(embeddings)
# Out:
# ARI :  0.6041 time :  61.0

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)
# Out:
# ARI :  0.6041

# %%
X_tsne
# Out:
# array([[  5.521129 , -16.988916 ],
#        [ -5.0379457,   7.310294 ],
#        [-30.140154 , -21.621614 ],
#        ...,
#        [ 40.07719  ,  14.0288315],
#        [-11.451014 ,   2.9613118],
#        [ 11.837343 ,  38.086407 ]], dtype=float32)

# %% [markdown]
# # BERT

# %%
import tensorflow as tf
# import tensorflow_hub as hub
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

# Bert
import os
import transformers
from transformers import *

os.environ["TF_KERAS"]='1'
# Out:
# c:\Users\DELL\anaconda3\lib\site-packages\transformers\generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# c:\Users\DELL\anaconda3\lib\site-packages\transformers\generation_tf_utils.py:24: FutureWarning: Importing `TFGenerationMixin` from `src/transformers/generation_tf_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import TFGenerationMixin` instead.
#   warnings.warn(

# %%
print(tf.__version__)
print(tensorflow.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
# Out:
# 2.10.0
# 2.10.0
# Num GPUs Available:  0
# False

# %% [markdown]
# ## Fonctions communes

# %%
# Fonction de préparation des sentences
def bert_inp_fct(sentences, bert_tokenizer, max_length) :
    input_ids=[]
    token_type_ids = []
    attention_mask=[]
    bert_inp_tot = []

    for sent in sentences:
        bert_inp = bert_tokenizer.encode_plus(sent,
                                              add_special_tokens = True,
                                              max_length = max_length,
                                              padding='max_length',
                                              return_attention_mask = True, 
                                              return_token_type_ids=True,
                                              truncation=True,
                                              return_tensors="tf")
    
        input_ids.append(bert_inp['input_ids'][0])
        token_type_ids.append(bert_inp['token_type_ids'][0])
        attention_mask.append(bert_inp['attention_mask'][0])
        bert_inp_tot.append((bert_inp['input_ids'][0], 
                             bert_inp['token_type_ids'][0], 
                             bert_inp['attention_mask'][0]))

    input_ids = np.asarray(input_ids)
    token_type_ids = np.asarray(token_type_ids)
    attention_mask = np.array(attention_mask)
    
    return input_ids, token_type_ids, attention_mask, bert_inp_tot
    

# Fonction de création des features
def feature_BERT_fct(model, model_type, sentences, max_length, b_size, mode='HF') :
    batch_size = b_size
    batch_size_pred = b_size
    bert_tokenizer = AutoTokenizer.from_pretrained(model_type)
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        input_ids, token_type_ids, attention_mask, bert_inp_tot = bert_inp_fct(sentences[idx:idx+batch_size], 
                                                                      bert_tokenizer, max_length)
        
        if mode=='HF' :    # Bert HuggingFace
            outputs = model.predict([input_ids, attention_mask, token_type_ids], batch_size=batch_size_pred)
            last_hidden_states = outputs.last_hidden_state

        if mode=='TFhub' : # Bert Tensorflow Hub
            text_preprocessed = {"input_word_ids" : input_ids, 
                                 "input_mask" : attention_mask, 
                                 "input_type_ids" : token_type_ids}
            outputs = model(text_preprocessed)
            last_hidden_states = outputs['sequence_output']
             
        if step ==0 :
            last_hidden_states_tot = last_hidden_states
            last_hidden_states_tot_0 = last_hidden_states
        else :
            last_hidden_states_tot = np.concatenate((last_hidden_states_tot,last_hidden_states))
    
    features_bert = np.array(last_hidden_states_tot).mean(axis=1)
    
    time2 = np.round(time.time() - time1,0)
    print("temps traitement : ", time2)
     
    return features_bert, last_hidden_states_tot

# %% [markdown]
# ## BERT HuggingFace

# %% [markdown]
# ### 'bert-base-uncased'

# %%
max_length = 64
batch_size = 10
model_type = 'bert-base-uncased'
model = TFAutoModel.from_pretrained(model_type)
sentences = data_T['sentence_dl'].to_list()

# %%
# Création des features

features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences, 
                                                         max_length, batch_size, mode='HF')
# Out:
# 1/1 [==============================] - 18s 18s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 831ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 852ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# temps traitement :  538.0

# %%
ARI, X_tsne, labels = ARI_fct(features_bert)
# Out:
# ARI :  0.6303 time :  63.0

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)
# Out:
# ARI :  0.6303

# %% [markdown]
# ### 'cardiffnlp/twitter-roberta-base-sentiment'
# * Modèle pré-entraîné sur des tweets pour l'analyse de sentiment = particulièrement adapté au contexte

# %%
max_length = 64
batch_size = 10
model_type = 'cardiffnlp/twitter-roberta-base-sentiment'
model = TFAutoModel.from_pretrained(model_type)
sentences = data_T['sentence_dl'].to_list()

# %%
features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences, 
                                                         max_length, batch_size, mode='HF')
# Out:
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 912ms/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 816ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 912ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 831ms/step
# 1/1 [==============================] - 1s 913ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 914ms/step
# 1/1 [==============================] - 1s 822ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 933ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 868ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 897ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 902ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 913ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 980ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 986ms/step
# 1/1 [==============================] - 1s 842ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 914ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 942ms/step
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 1s 986ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 890ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 894ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 902ms/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 903ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 953ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 999ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 928ms/step
# 1/1 [==============================] - 1s 894ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 965ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences,
#       2                                                          max_length, batch_size, mode='HF')
#
# Cell In[38], line 45, in feature_BERT_fct(model, model_type, sentences, max_length, b_size, mode)
#      41 input_ids, token_type_ids, attention_mask, bert_inp_tot = bert_inp_fct(sentences[idx:idx+batch_size],
#      42                                                               bert_tokenizer, max_length)
#      44 if mode=='HF' :    # Bert HuggingFace
# ---> 45     outputs = model.predict([input_ids, attention_mask, token_type_ids], batch_size=batch_size_pred)
#      46     last_hidden_states = outputs.last_hidden_state
#      48 if mode=='TFhub' : # Bert Tensorflow Hub
#
# File c:\Users\DELL\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\DELL\anaconda3\lib\site-packages\keras\engine\training.py:2253, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2251 for step in data_handler.steps():
#    2252     callbacks.on_predict_batch_begin(step)
# -> 2253     tmp_batch_outputs = self.predict_function(iterator)
#    2254     if data_handler.should_sync:
#    2255         context.async_wait()
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
ARI, X_tsne, labels = ARI_fct(features_bert)

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)

# %% [markdown]
# ## BERT hub Tensorflow

# %%
import tensorflow_hub as hub
import tensorflow_text 

# Guide sur le Tensorflow hub : https://www.tensorflow.org/text/tutorials/classify_text_with_bert
model_url = 'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4'
bert_layer = hub.KerasLayer(model_url, trainable=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import tensorflow_hub as hub
# ----> 2 import tensorflow_text
#       4 # Guide sur le Tensorflow hub : https://www.tensorflow.org/text/tutorials/classify_text_with_bert
#       5 model_url = 'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4'
#
# ModuleNotFoundError: No module named 'tensorflow_text'

# %%
sentences = data_T['sentence_dl'].to_list()

# %%
max_length = 64
batch_size = 10
model_type = 'bert-base-uncased'
model = bert_layer

features_bert, last_hidden_states_tot = feature_BERT_fct(model, model_type, sentences, 
                                                         max_length, batch_size, mode='TFhub')

# %%
ARI, X_tsne, labels = ARI_fct(features_bert)

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)

# %% [markdown]
# # USE - Universal Sentence Encoder

# %%
import tensorflow as tf
# import tensorflow_hub as hub
import tensorflow.keras
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import metrics as kmetrics
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

# Bert
import transformers
from transformers import *

os.environ["TF_KERAS"]='1'

# %%
print(tf.__version__)
print(tensorflow.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())

# %%
import tensorflow_hub as hub

embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
def feature_USE_fct(sentences, b_size) :
    batch_size = b_size
    time1 = time.time()

    for step in range(len(sentences)//batch_size) :
        idx = step*batch_size
        feat = embed(sentences[idx:idx+batch_size])

        if step ==0 :
            features = feat
        else :
            features = np.concatenate((features,feat))

    time2 = np.round(time.time() - time1,0)
    return features

# %%
batch_size = 10
sentences = data_T['sentence_dl'].to_list()

# %%
features_USE = feature_USE_fct(sentences, batch_size)

# %%
ARI, X_tsne, labels = ARI_fct(features_USE)

# %%
TSNE_visu_fct(X_tsne, y_cat_num, labels, ARI)
